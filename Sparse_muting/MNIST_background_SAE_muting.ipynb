# %%
from google.colab import drive
drive.mount("/content/drive")
dir_path = "/content/drive/MyDrive/Masterthesis/Datasets/mnist"
# Out:
# Mounted at /content/drive

# %%
# !pip install torchextractor
# Out:
# Collecting torchextractor
#   Downloading torchextractor-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchextractor) (1.26.4)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from torchextractor) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->torchextractor) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->torchextractor) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.4.0->torchextractor) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.4.0->torchextractor) (3.0.2)
# Downloading torchextractor-0.3.0-py3-none-any.whl (10 kB)
# Installing collected packages: torchextractor
# Successfully installed torchextractor-0.3.0

# %%
import torch
import sys
import numpy as np
import pickle as pkl
from os.path import join as oj
from datetime import datetime
import torch.optim as optim
import os
from torch.utils.data import TensorDataset, ConcatDataset
from sklearn.metrics import roc_auc_score, precision_recall_curve, auc, f1_score
import argparse
from PIL import Image
from tqdm import tqdm
from torch import nn
from numpy.random import randint
import torchvision.models as models
import time
import copy
import gc
import json
import pandas as pd
import torch
import torchvision.models as models
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, ConcatDataset, random_split
from PIL import Image
import torch.nn as nn
import matplotlib.pyplot as plt
import time
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.optim.lr_scheduler import StepLR
from scipy.stats import ttest_1samp
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.functional as F
import torch.nn as nn
import numpy as np
import os
import gc
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Loading fine tuned alexnet

# %%
class MnistDataset(Dataset):
    def __init__(self, path: str = None, is_two: int = None, data_files=None, labels=None, transform=None):
        self.resize_shape = (64, 64)
        self.transform = transform or transforms.Compose([
            transforms.Resize(self.resize_shape),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

        if path:
            self.path = path
            self.data_files = [f for f in os.listdir(self.path) if f.endswith(('.jpg', '.png'))]
            if len(self.data_files) == 0:
                raise ValueError(f"No valid image files found in the provided path: {self.path}")

            self.is_two = is_two
            self.labels = [is_two] * len(self.data_files) if is_two is not None else labels
        else:
            self.path = ''
            if data_files is None or len(data_files) == 0:
                raise ValueError("data_files must be a non-empty list of file paths.")

            self.data_files = data_files
            self.labels = labels
            self.is_two = is_two

        if self.labels is not None and len(self.labels) != len(self.data_files):
            raise ValueError("Mismatch between the number of labels and data files.")

    def __getitem__(self, i):
        try:
            img_path = os.path.join(self.path, self.data_files[i]) if self.path else self.data_files[i]
            img = Image.open(img_path).convert("RGB") #!!!!!
            if self.transform:
                img = self.transform(img)

            is_two = self.is_two if self.is_two is not None else self.labels[i]
            return img, is_two  # Exclude group_label
        except Exception as e:
            print(f"Error processing index {i}: {e}")
            return None

    def __len__(self):
        return len(self.data_files)

# %%
mean = np.asarray([0.485, 0.456, 0.406])
std = np.asarray([0.229, 0.224, 0.225])

'''
def load_model(model_path, device):
    print(f"Loading model from {model_path}")
    model = models.alexnet(pretrained=False)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.classifier[-1] = nn.Linear(4096, 2)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    print("Model loaded successfully")
    return model
'''


# Function to load the trained model
def load_model(model_path, device):
    print(f"Loading model from {model_path}")
    model = models.alexnet(pretrained=False)
    model.classifier[-1] = nn.Linear(4096, 2)

    #model = AlexNet().to(device)
    #model.fc3 = nn.Linear(4096, 2)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    print("Model loaded successfully")
    return model

# %% [markdown]
# ### Extract Alexnet training fc2 activations

# %%
class ImageDataset(Dataset):
    def __init__(self, image_paths, transform=None, resize_shape=(64, 64)):
        print(f"Initializing dataset with {len(image_paths)} images")
        self.image_paths = image_paths
        self.resize_shape = resize_shape  # Set the resize shape
        self.transform = transform or transforms.Compose([
            transforms.Resize(self.resize_shape),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize for RGB images
        ])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        print(f"Loading image: {image_path}")
        image = Image.open(image_path).convert("RGB") #!!!!!!!!!!!
        if self.transform:
            image = self.transform(image)
        return image


# Preprocessing function
preprocess = transforms.Compose([
    #transforms.Grayscale(num_output_channels=3),
    transforms.Resize((64, 64)),  # Match the resize shape in MnistDataset
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Match the normalization values in MnistDataset
])

# %%
def load_model(model_path):
    print(f"Loading model from {model_path}")
    model = models.alexnet(pretrained=True)
    #model = AlexNet().to(device)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    #model.fc3 = nn.Linear(4096, 2)
    model.classifier[-1] = nn.Linear(4096, 2)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()
    print("Model loaded successfully")

    # Freeze all layers
    for param in model.parameters():
        param.requires_grad = False

    print("Model loaded and layers frozen successfully")

    # Add a forward hook to capture fc2 activations
    activations = {}

    def hook(module, input, output):
        activations["fc2"] = output

    # Attach the hook to the second last layer (fc2)
    #model.fc2[1].register_forward_hook(hook)
    model.classifier[4].register_forward_hook(hook)

    return model, activations





def preprocess_and_extract_activations(model, dataloader, layer):

    activations = []
    with torch.no_grad():
        for batch in dataloader:
            image_tensor = batch[0]  # Extract the image tensor (ignore labels)
            image_tensor = image_tensor.to(device)

            if layer < 13:  # Layer in model.features
                tensor = image_tensor
                for idx, layer_module in enumerate(model.features[:layer + 1]):
                    tensor = layer_module(tensor)
            else:  # Layer in model.classifier
                tensor = model.features(image_tensor)
                tensor = model.avgpool(tensor)
                tensor = torch.flatten(tensor, 1)
                for idx, layer_module in enumerate(model.classifier[:layer - 12]):
                    tensor = layer_module(tensor)
                    if idx == 4:
                      print(f"Extracting from FC2 (classifier[4]): {layer_module}")
                      print(f"Activation shape at FC2: {tensor.shape}")


            activation = tensor.cpu().numpy()
            activations.append(activation)

    print(f"Extracted activations for {len(activations)} images")
    return activations


def process_images_in_folder(model, folder_path, layer, is_two, batch_size=1):
    all_layer_activations = []

    # Ensure folder_path is a string
    if not isinstance(folder_path, str):
        raise ValueError(f"Expected folder_path to be a string, but got {type(folder_path)}")

    # Get all image file paths
    image_paths = [os.path.join(root, file)
                   for root, dirs, files in os.walk(folder_path)
                   for file in files if file.endswith(('.jpg', '.png'))]

    if len(image_paths) == 0:
        raise ValueError(f"No image files found in folder: {folder_path}")

    print(f"Initializing dataset with {len(image_paths)} images and is_two={is_two}")
    # Create the dataset and DataLoader
    dataset = ImageDataset(image_paths=image_paths, transform=preprocess)
    print(f"Dataset initialized with {len(dataset)} items.")
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    # Prepare dictionary for activations
    activations_dict = {}

    # Define the hook for the specified layer
    def hook(module, input, output):
        activations_dict[layer] = output

    # Register hook for the specified layer
    if layer == 'fc2':
        model.classifier[4].register_forward_hook(hook)  # Attach to fc2's Linear layer

    # Iterate over the dataloader to extract activations
    for images in dataloader:  # Only images are returned by the dataset
        if images is None:
            print("Skipping invalid batch.")
            continue

        images = images.to(next(model.parameters()).device)  # Move images to the same device as the model
        _ = model(images)  # Forward pass to trigger hooks

        # Collect activations from the specified layer
        if layer in activations_dict:
            all_layer_activations.append(activations_dict[layer].cpu().numpy())

    if len(all_layer_activations) == 0:
        raise ValueError("No activations were collected. Check dataset or model.")

    # Concatenate activations if batched
    all_layer_activations = np.concatenate(all_layer_activations, axis=0)

    # Free resources
    torch.cuda.empty_cache()
    gc.collect()

    return all_layer_activations

# %%
def flatten_and_align_activations(activations_list):
    print("Flattening and aligning activations")
    flat_activations = [act.flatten() for act in activations_list]
    max_length = max(len(act) for act in flat_activations)

    aligned_activations = []
    for activation in flat_activations:
        if len(activation) < max_length:
            padded_activation = np.pad(activation, (0, max_length - len(activation)), 'constant')
        else:
            padded_activation = activation[:max_length]
        aligned_activations.append(padded_activation)
    print(f"Aligned activations to shape: {np.vstack(aligned_activations).shape}")
    return np.vstack(aligned_activations)


def save_activations(activations, folder_name, filename): #?????
    try:
        drive_path = f'/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/individual/{folder_name}/background/{filename}.npy'
        os.makedirs(os.path.dirname(drive_path), exist_ok=True)
        print(f"Saving activations to {drive_path}")
        np.save(drive_path, activations)
    except Exception as e:
        print(f"Error saving activations to {drive_path}: {e}")

def load_activations(folder_name, filename):
    try:
        drive_path = f'/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/individual/{folder_name}/background/{filename}.npy'
        print(f"Loading activations from {drive_path}")
        return np.load(drive_path, allow_pickle=True)
    except FileNotFoundError:
        print(f"Activations not found at {drive_path}")
        return None

# %%
def compute_activations_for_layers(model_paths, folder_paths, layers, activations_file_prefix):
    # Initialize the dictionary with all keys in folder_paths
    all_layer_activations = {layer: {key: [] for key in folder_paths.keys()} for layer in layers}

    for folder_name, folder_path in folder_paths.items():
        print(f"Processing folder {folder_name}")

        # Get the is_two value from the mapping
        is_two = is_two_mapping.get(folder_name)
        if is_two is None:
            raise ValueError(f"Unknown folder name: {folder_name}. Please update is_two_mapping.")

        for layer in layers:
            for model_idx, model_path in enumerate(model_paths):
                print(f"Processing model {model_idx + 7}/{len(model_paths)}")
                model, activations_dict = load_model(model_path)

                def hook(module, input, output):
                    activations_dict[layer] = output

                model.classifier[4].register_forward_hook(hook)

                # Pass is_two when creating the dataset

                activations = process_images_in_folder(model, folder_path, layer, is_two=is_two, batch_size=1)
                activations = flatten_and_align_activations(activations)

                # Save activations for this model and folder
                model_specific_file_prefix = f'{activations_file_prefix}_model{model_idx + 7}_{folder_name}'
                save_activations(activations, f'layer_{layer}', model_specific_file_prefix)

                all_layer_activations[layer][folder_name].append(activations)

                del model
                torch.cuda.empty_cache()
                gc.collect()

    return all_layer_activations






# Step 2: Extract Training Activations

model_paths = [
    #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1.pt",
    #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_11.pt",
    #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_111.pt",
    #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1111.pt",
    #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_11111.pt",
    #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_111111.pt",
    "/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1111111.pt"


]

layers_of_interest = ['fc2']

is_two_mapping = {
    'two_no_patch': 1,
    'zero_no_patch': 0,
    'zero_patch': 0
}


# Paths to training data
train_folder_paths = {
    'two_no_patch': '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_2',
    'zero_no_patch': '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0',
    'zero_patch': '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/train/class_0'
}


val_folder_paths = {
    'two_no_patch': '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/val/class_2',
    'zero_no_patch': '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/val/class_0',
    'zero_patch': '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0'
}


# Extract and save averaged training activations across three models
#train_activations = compute_activations_for_layers(model_paths, train_folder_paths, layers_of_interest, 'train')
#val_activations = compute_activations_for_layers(model_paths, val_folder_paths, layers_of_interest, 'val')
# Out:
# Processing folder two_no_patch
# Processing model 7/1
# Loading model from /content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1111111.pt
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 205MB/s]
# <ipython-input-8-7d9def5810e6>:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Streaming output truncated to the last 5000 lines.
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2366.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2367.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_237.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2371.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2372.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2373.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2374.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2375.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2376.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2377.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2378.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_238.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2380.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2381.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2382.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2383.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2385.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2386.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2387.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2388.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2389.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_239.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2390.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2391.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2392.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2393.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2394.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2395.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2396.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2397.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2398.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2399.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_24.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_240.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2400.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2401.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2402.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2403.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2404.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2405.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2406.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2407.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2408.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2409.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_241.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2411.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2412.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2415.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2416.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2420.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2423.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2424.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2425.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2426.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2429.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_243.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2430.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2433.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2434.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2435.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2436.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2437.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2439.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_244.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2440.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2441.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2442.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2443.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2444.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2446.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2447.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2449.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_245.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2450.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2451.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2452.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2453.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2454.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2455.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2456.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2457.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2458.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2459.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2460.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2461.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2463.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2464.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2465.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2466.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2467.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2468.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2469.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_247.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2470.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2471.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2472.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2473.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2474.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2476.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2477.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2478.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2479.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2480.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2481.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2482.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2483.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2484.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2485.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2486.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2487.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2488.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2489.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_249.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2490.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2491.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2492.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2493.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2495.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2496.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2498.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2499.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_25.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_250.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2500.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2502.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2504.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2505.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2507.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2508.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2509.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2510.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2511.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2512.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2513.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2514.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2517.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_2518.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_0.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_10.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1000.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1001.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1002.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1005.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1006.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1007.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1008.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1009.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_101.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1010.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1011.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1013.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1014.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1015.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1016.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1017.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1018.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1019.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_102.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1021.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1022.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1023.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1024.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1025.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1026.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1027.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1028.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1029.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_103.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1030.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1031.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1032.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1034.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1036.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1038.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1039.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_104.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1040.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1042.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1044.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1045.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1046.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1047.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1048.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1049.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_105.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1050.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1051.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1053.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1052.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1054.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1055.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1056.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1058.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1059.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_106.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1060.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1061.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1063.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1065.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1066.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1068.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1069.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_107.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1071.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1073.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1074.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1075.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1076.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1077.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1078.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_108.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1082.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1083.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1084.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1086.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1087.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1088.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1089.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_109.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1090.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1091.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1092.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1094.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1095.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1096.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1098.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_11.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_110.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1101.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1102.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1103.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1104.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1106.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1107.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1108.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1109.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_111.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1110.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1111.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1112.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1113.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1116.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1117.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1119.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_112.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1120.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1121.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1122.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1123.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1124.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1126.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1128.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1129.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_113.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1130.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1131.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1132.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1133.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1135.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1136.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1137.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1138.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1139.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_114.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1140.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1142.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1143.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1144.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1145.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1146.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1148.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_115.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1150.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1152.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1153.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1154.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1156.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1157.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1158.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1159.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_116.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1160.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1163.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1164.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1165.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1166.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1167.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1168.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1169.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_117.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1170.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1173.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1174.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1175.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1176.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1177.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1179.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_118.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1180.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1181.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1183.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1184.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1186.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1188.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1189.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_119.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1190.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1191.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1192.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1193.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1194.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1195.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1196.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1197.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1198.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1199.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_120.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1201.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1202.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1204.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1205.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1206.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1207.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1208.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1209.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_121.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1210.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1211.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1212.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1213.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1214.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1215.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1216.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1217.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1218.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1219.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_122.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1220.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1221.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1222.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1224.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1225.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1226.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1227.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1228.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1229.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_123.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1230.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1231.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1232.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1234.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1235.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1236.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1238.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1239.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_124.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1240.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1241.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1242.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1243.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1244.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1246.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1247.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1248.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1249.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_125.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1250.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1251.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1252.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1253.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1254.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1255.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1256.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1257.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1258.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1259.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1260.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1261.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1262.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1264.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1265.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1266.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1267.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1268.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1269.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_127.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1270.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1271.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1272.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1273.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1274.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1275.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1277.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1278.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1279.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_128.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1280.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1282.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/train/class_0/0_1285.png
# ...
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4544.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4549.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4564.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4565.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4573.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4577.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4593.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4594.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4602.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4604.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4610.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4619.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4621.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4627.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4630.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4631.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4636.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4655.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4660.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4662.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4671.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4681.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4680.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4697.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4695.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4703.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4716.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4720.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4731.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4735.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4738.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4742.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4744.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4749.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4750.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4756.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4767.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4771.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4782.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4784.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4788.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4798.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4803.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4808.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4811.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4813.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4814.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4815.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4817.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4822.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4824.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4827.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4826.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4835.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4836.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4856.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4860.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4861.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4870.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4876.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4881.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4882.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4888.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4892.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_4896.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3661.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3659.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3664.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3671.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3672.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3673.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3679.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3683.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3690.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3701.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3712.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3714.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3718.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3723.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3735.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3747.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3752.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3753.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3759.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3762.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3764.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3765.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3769.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3768.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3777.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3781.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3779.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3792.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3801.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3802.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3808.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3814.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3817.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3837.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3839.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3838.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3844.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3842.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3856.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3859.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3863.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3868.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3875.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3884.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3886.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3888.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3901.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3906.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_3914.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_47.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_49.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_376.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_378.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_390.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_394.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_396.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_412.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_418.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_419.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_427.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_438.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_440.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_442.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_445.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_460.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_468.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_469.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_471.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_479.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_502.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_505.png
# Loading image: /content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0/0_507.png
# Flattening and aligning activations
# Aligned activations to shape: (296, 4096)
# Saving activations to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/individual/layer_fc2/background/val_model7_zero_patch.npy

# %% [markdown]
# ### Load saved activations of the fc2 alexnet training to later train the SAE

# %%
import os
import numpy as np
'''
def load_saved_activations(subset, activations_file_prefix, model_idx=None, dataset_type="train"):
    """
    Load saved activations from files with the format: {dataset_type}_model{idx}_{subset}.npy.

    Parameters:
        subset (str): The data subset (e.g., "two_no_patch", "zero_no_patch", "zero_patch").
        activations_file_prefix (str): File prefix for the activations.
        model_idx (int or None): Specific model index to load (e.g., 1, 2, 3). If None, load all models.
        dataset_type (str): The dataset type ("train" or "val").

    Returns:
        np.ndarray or List[np.ndarray]: Loaded activations for a specific model (if model_idx is provided)
                                        or a list of activations for all models.
    """
    activations = []

    if model_idx is not None:
        # Load activations for a specific model
        drive_path = f'/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/individual/layer_fc2/{dataset_type}_model{model_idx}_{subset}.npy'
        print(f"Loading activations from {drive_path}")

        if os.path.exists(drive_path):
            model_activations = np.load(drive_path, allow_pickle=True)
            print(f"Loaded activations for subset {subset}, dataset {dataset_type}, model {model_idx}. Shape: {model_activations.shape}")
            return model_activations
        else:
            print(f"Activations file {drive_path} does not exist.")
            return None
    else:
        # Load activations for all models
        for idx in range(1, 4):  # Adjust the range based on the number of models
            drive_path = f'/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/individual/layer_fc2/{dataset_type}_model{idx}_{subset}.npy'
            print(f"Loading activations from {drive_path}")

            if os.path.exists(drive_path):
                model_activations = np.load(drive_path, allow_pickle=True)
                print(f"Loaded activations for subset {subset}, dataset {dataset_type}, model {idx}. Shape: {model_activations.shape}")
                activations.append(model_activations)
            else:
                print(f"Activations file {drive_path} does not exist.")

        if len(activations) > 0:
            print(f"Loaded activations for {len(activations)} model(s).")
            return activations  # List of numpy arrays, one for each model
        else:
            print("No activations files found.")
            return None
'''

# %%
# Step 2: Define Sparse Autoencoder with KL-divergence
class SparseAutoencoder(nn.Module):
    def __init__(self, in_dims, h_dims, sparsity_lambda=1.5, sparsity_target=0.20, xavier_norm_init=True):
        super(SparseAutoencoder, self).__init__()
        self.in_dims = in_dims  # Input dimension (number of neurons in the input layer)
        self.h_dims = h_dims  # Hidden dimension (number of neurons in the hidden layer)
        self.sparsity_lambda = sparsity_lambda  # Weight for the sparsity penalty term
        self.sparsity_target = sparsity_target  # Target sparsity (desired average activation)

        # Encoder: Projects input to the hidden (sparse) space
        self.encoder = nn.Sequential(
            nn.Linear(self.in_dims, self.h_dims),
            nn.ReLU()
        )
        if xavier_norm_init:
            nn.init.xavier_uniform_(self.encoder[0].weight)  # Xavier initialization

        # Decoder: Reconstructs the input from the hidden (sparse) representation
        self.decoder = nn.Sequential(
            nn.Linear(self.h_dims, self.in_dims),
            #nn.ReLU()
        )
        if xavier_norm_init:
            nn.init.xavier_uniform_(self.decoder[0].weight)

    # Forward pass through the encoder and decoder
    def forward(self, x):
        encoded = self.encoder(x)  # Pass input through encoder
        decoded = self.decoder(encoded)  # Pass encoded (sparse) representation through decoder
        return encoded, decoded


    def kl_sparsity_penalty(self, encoded):
        # Penalize the average absolute activation
        rho_hat = torch.mean(torch.abs(encoded), dim=0)  # Average absolute activation per hidden unit
        rho = torch.ones_like(rho_hat) * self.sparsity_target  # Target sparsity value
        epsilon = 1e-8  # Small value to avoid log(0)

        # KL-divergence computation for sparsity
        kl_divergence = rho * torch.log(rho / (rho_hat + epsilon)) + (1 - rho) * torch.log((1 - rho) / (1 - rho_hat + epsilon))
        kl_divergence = torch.sum(kl_divergence)  # Sum over all hidden units

        return self.sparsity_lambda * kl_divergence



    # L1-norm sparsity penalty calculation
    def l1_sparsity_penalty(self, encoded):
        # Compute the mean of absolute values of activations
        sparsity_loss = torch.mean(torch.abs(encoded))  # Average absolute activation across all units
        return self.sparsity_lambda * sparsity_loss  # Scale by the sparsity weight


    # KL-divergence sparsity penalty calculation
    def old_kl_sparsity_penalty(self, encoded):
        rho_hat = torch.mean(encoded, dim=0)  # Compute the average activation for each hidden neuron
        rho = torch.ones_like(rho_hat) * self.sparsity_target  # Target sparsity value
        epsilon = 1e-8  # Small value to avoid log(0)
        kl_divergence = F.kl_div((rho_hat + epsilon).log(), rho + epsilon, reduction='batchmean')  # KL-divergence
        return self.sparsity_lambda * kl_divergence  # Return the sparsity penalty, weighted by lambda

    # Loss function combining MSE (reconstruction error) and sparsity penalty
    def loss_function(self, decoded, original, encoded):
        mse_loss = F.mse_loss(decoded, original)  # Mean Squared Error for reconstruction
        sparsity_loss = self.l1_sparsity_penalty(encoded)  # Sparsity penalty for hidden layer activations
        return mse_loss + sparsity_loss  # Total loss is MSE + sparsity penalty


# Early stopping mechanism to prevent overfitting
class EarlyStopping:
    def __init__(self, patience=20, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta  # Minimum change to qualify as an improvement
        self.best_loss = None  # Best validation loss observed so far
        self.counter = 0  # Counter to keep track of how many epochs since the last improvement

    # Check if training should be stopped based on validation loss
    def check(self, loss):
        if self.best_loss is None:
            self.best_loss = loss  # Set the initial best loss
            return False

        # If the loss has improved significantly
        if loss < self.best_loss - self.min_delta:
            self.best_loss = loss  # Update best loss
            self.counter = 0  # Reset counter
            return False
        else:
            self.counter += 1  # Increment counter if no improvement
            if self.counter >= self.patience:
                print("Early stopping triggered.")  # Stop training if patience is exceeded
                return True
        return False


# Training Function with Loss Tracking and Plotting
def train_autoencoder(autoencoder, train_data, val_data, num_epochs=500, batch_size=128, learning_rate=1e-4, validation_split=0.2, clip_gradients=True, max_grad_norm=0.5):
    #print(f"Training autoencoder with input dim {data.shape[1]} and encoding dim {autoencoder.h_dims}")

    # Split the data into training and validation sets
    #num_train = int((1 - validation_split) * len(data))  # Compute the number of training samples
    #train_data = data[:num_train]  # Training data
    #val_data = data[num_train:]  # Validation data

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    train_tensor = torch.from_numpy(train_data).float()
    val_tensor = torch.from_numpy(val_data).float()
    # Create PyTorch datasets and dataloaders for training and validation
    train_dataset = torch.utils.data.TensorDataset(torch.from_numpy(train_data).float())
    val_dataset = torch.utils.data.TensorDataset(torch.from_numpy(val_data).float())
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Adam optimizer with learning rate and weight decay for regularization
    optimizer = torch.optim.Adam(autoencoder.parameters(), lr=learning_rate, weight_decay=1e-2)

    # Initialize early stopping
    early_stopping = EarlyStopping(patience=30, min_delta=0.001)

    # Lists to store training and validation loss values
    train_losses = []
    val_losses = []

    # Start training loop
    autoencoder.train()  # Set the autoencoder in training mode
    for epoch in range(num_epochs):
        total_train_loss = 0  # Initialize training loss for the current epoch

        # Iterate over batches in the training set
        for x_batch, in train_loader:
            x_batch = x_batch.to(device)
            optimizer.zero_grad()  # Zero the gradients
            encoded, decoded = autoencoder(x_batch)  # Forward pass through autoencoder
            loss = autoencoder.loss_function(decoded, x_batch, encoded)  # Compute the loss
            loss.backward()  # Backpropagate the error

            # Apply gradient clipping if enabled
            if clip_gradients:
                torch.nn.utils.clip_grad_norm_(autoencoder.parameters(), max_grad_norm)

            optimizer.step()  # Update the weights using the optimizer
            total_train_loss += loss.item()  # Accumulate training loss for this batch

        # Validation step after each epoch
        total_val_loss = 0  # Initialize validation loss
        autoencoder.eval()  # Set the autoencoder in evaluation mode
        with torch.no_grad():  # No gradient calculation in validation mode
            for x_batch, in val_loader:
                x_batch = x_batch.to(device)
                encoded, decoded = autoencoder(x_batch)
                loss = autoencoder.loss_function(decoded, x_batch, encoded)
                total_val_loss += loss.item()

        # Compute the average training and validation loss for this epoch
        avg_train_loss = total_train_loss / len(train_loader)
        avg_val_loss = total_val_loss / len(val_loader)

        # Store the loss values for plotting later
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # Print progress for the current epoch
        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {avg_train_loss}, Val Loss: {avg_val_loss}')

        # Check early stopping condition based on validation loss
        if early_stopping.check(avg_val_loss):
            break

    print("Autoencoder training completed")

    # Plot the training and validation loss over epochs
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
    plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss over Epochs')
    plt.legend()
    plt.grid(True)
    plt.show()

    return autoencoder

# %%
'''
####THIS IS THE CURRENT VERSION
# Define the directory to save autoencoders trained on normalized activations
save_sae_dir = '/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background'  # Directory to save the trained autoencoder
os.makedirs(save_sae_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Iterate through layers of interest
for layer in layers_of_interest:
    print(f'\nTraining autoencoders for layer {layer}')

    # Iterate through seeds (corresponding to models)
    for seed_idx, seed in enumerate([1111111], start=7): #!!!!!!! start at 7 instead of 1
        print(f"\nProcessing activations for layer {layer}, seed {seed} (Model {seed_idx})") #!!!!remove+7

        # Get training activations for the current seed and layer
        train_activations_list = []
        print(f"\nTrain files associated with seed {seed}:")
        idx = seed_idx
        for subset in ['two_no_patch', 'zero_no_patch', 'zero_patch']:
            train_file_path = f'/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/individual/layer_fc2/background/train_model{idx}_{subset}.npy'
            if os.path.exists(train_file_path):
                subset_activations = train_activations[layer][subset][seed_idx - 7]  # Seed index starts from 1, Python lists are 0-based !!!!! from -1 to -7
                train_activations_list.append(subset_activations)
                print(f"  - Subset: {subset}, File: train_model{seed_idx}_{subset}.npy")
            else:
                print(f"Warning: No train activations found for subset {subset}, layer {layer}, seed {seed}.")

        if len(train_activations_list) == 0:
            print(f"No train activations found for layer {layer}, seed {seed}. Skipping...")
            continue

        # Combine train activations
        combined_train_activations = np.vstack(train_activations_list)
        print(f"Combined train activations shape for layer {layer}, seed {seed}: {combined_train_activations.shape}")

        # Get validation activations for the current seed and layer
        val_activations_list = []
        print(f"\nValidation files associated with seed {seed}:")
        idx= seed_idx
        for subset in ['two_no_patch', 'zero_no_patch', 'zero_patch']:
            val_file_path = f'/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/individual/layer_fc2/background/val_model{idx}_{subset}.npy'
            if os.path.exists(val_file_path):
                subset_activations = val_activations[layer][subset][seed_idx - 7] #!!!!!! from -1 to -7
                val_activations_list.append(subset_activations)
                print(f"  - Subset: {subset}, File: val_model{seed_idx}_{subset}.npy")
            else:
                print(f"Warning: No val activations found for subset {subset}, layer {layer}, seed {seed}.")

        if len(val_activations_list) == 0:
            print(f"No val activations found for layer {layer}, seed {seed}. Skipping...")
            continue

        # Combine val activations
        combined_val_activations = np.vstack(val_activations_list)
        print(f"Combined val activations shape for layer {layer}, seed {seed}: {combined_val_activations.shape}")

        # Set the random seed for reproducibility
        torch.manual_seed(seed)
        np.random.seed(seed)

        # Define encoding dimension
        encoding_dim = 16000

        # Train autoencoder on unnormalized activations
        autoencoder = SparseAutoencoder(combined_train_activations.shape[1], encoding_dim).to(device)
        print(f"Training autoencoder for layer {layer} (unnormalized, seed {seed})")
        autoencoder = train_autoencoder(autoencoder, combined_train_activations, combined_val_activations,
                                        num_epochs=500, learning_rate=1e-4)

        # Save the trained autoencoder
        save_path_unnormalized = os.path.join(
            save_sae_dir, f'l1_bg_autoencoder_layer_{layer}_seed_{seed}.pth'
        )
        torch.save(autoencoder.state_dict(), save_path_unnormalized)
        print(f"Saved unnormalized autoencoder at {save_path_unnormalized}")

        # Clear memory
        del autoencoder
        torch.cuda.empty_cache()
        gc.collect()

print("\nAll autoencoders trained and saved successfully.")
'''
# Out:
# Training autoencoders for layer fc2
#
# Processing activations for layer fc2, seed 1111111 (Model 7)
#
# Train files associated with seed 1111111:
#   - Subset: two_no_patch, File: train_model7_two_no_patch.npy
#   - Subset: zero_no_patch, File: train_model7_zero_no_patch.npy
#   - Subset: zero_patch, File: train_model7_zero_patch.npy
# Combined train activations shape for layer fc2, seed 1111111: (9504, 4096)
#
# Validation files associated with seed 1111111:
#   - Subset: two_no_patch, File: val_model7_two_no_patch.npy
#   - Subset: zero_no_patch, File: val_model7_zero_no_patch.npy
#   - Subset: zero_patch, File: val_model7_zero_patch.npy
# Combined val activations shape for layer fc2, seed 1111111: (2079, 4096)
# Training autoencoder for layer fc2 (unnormalized, seed 1111111)
# Epoch 1/500, Train Loss: 0.876558690071106, Val Loss: 0.5693766124108258
# Epoch 2/500, Train Loss: 0.5161474887530009, Val Loss: 0.4900171686621273
# Epoch 3/500, Train Loss: 0.46142281889915465, Val Loss: 0.4522473216056824
# Epoch 4/500, Train Loss: 0.4298244329293569, Val Loss: 0.4281750286326689
# Epoch 5/500, Train Loss: 0.40979810992876686, Val Loss: 0.41077976016437306
# Epoch 6/500, Train Loss: 0.3948408814271291, Val Loss: 0.3979339056155261
# Epoch 7/500, Train Loss: 0.38329586148262024, Val Loss: 0.38912633061408997
# Epoch 8/500, Train Loss: 0.3751292316118876, Val Loss: 0.38096421431092653
# Epoch 9/500, Train Loss: 0.3679916842778524, Val Loss: 0.37475039503153634
# Epoch 10/500, Train Loss: 0.36208101113637287, Val Loss: 0.36924978740075054
# Epoch 11/500, Train Loss: 0.3564910940329234, Val Loss: 0.3655985961942112
# Epoch 12/500, Train Loss: 0.3526684546470642, Val Loss: 0.3611811329336727
# Epoch 13/500, Train Loss: 0.3500347189108531, Val Loss: 0.3578619623885435
# Epoch 14/500, Train Loss: 0.3459866189956665, Val Loss: 0.35573460249339833
# Epoch 15/500, Train Loss: 0.3437274420261383, Val Loss: 0.35297129610005545
# Epoch 16/500, Train Loss: 0.3411145106951396, Val Loss: 0.3504241284202127
# Epoch 17/500, Train Loss: 0.3389155912399292, Val Loss: 0.34827261637238893
# Epoch 18/500, Train Loss: 0.3366586144765218, Val Loss: 0.346649425871232
# Epoch 19/500, Train Loss: 0.3354574791590373, Val Loss: 0.344781030626858
# Epoch 20/500, Train Loss: 0.33413715998331706, Val Loss: 0.3432582792113809
# Epoch 21/500, Train Loss: 0.3324672714869181, Val Loss: 0.3417380680056179
# Epoch 22/500, Train Loss: 0.33096167802810667, Val Loss: 0.3405205291860244
# Epoch 23/500, Train Loss: 0.3308318249384562, Val Loss: 0.3390946090221405
# Epoch 24/500, Train Loss: 0.3280066907405853, Val Loss: 0.3381810065578012
# Epoch 25/500, Train Loss: 0.327371559937795, Val Loss: 0.33709171589683085
# Epoch 26/500, Train Loss: 0.32619844635327655, Val Loss: 0.33608362604590025
# Epoch 27/500, Train Loss: 0.32530112147331236, Val Loss: 0.3351739154142492
# Epoch 28/500, Train Loss: 0.32451135516166685, Val Loss: 0.33468838824945335
# Epoch 29/500, Train Loss: 0.323741086324056, Val Loss: 0.3333343127194573
# Epoch 30/500, Train Loss: 0.32299673517545063, Val Loss: 0.33287645262830395
# Epoch 31/500, Train Loss: 0.3219571836789449, Val Loss: 0.3320024837465847
# Epoch 32/500, Train Loss: 0.3215121678511302, Val Loss: 0.331216317765853
# Epoch 33/500, Train Loss: 0.3211261308193207, Val Loss: 0.33062557963763967
# Epoch 34/500, Train Loss: 0.31997793952624004, Val Loss: 0.3303912737790276
# Epoch 35/500, Train Loss: 0.31989952047665915, Val Loss: 0.32974562399527607
# Epoch 36/500, Train Loss: 0.3196266531944275, Val Loss: 0.3292655383839327
# Epoch 37/500, Train Loss: 0.31876899480819704, Val Loss: 0.32867805221501517
# Epoch 38/500, Train Loss: 0.31749438007672626, Val Loss: 0.32820336082402396
# Epoch 39/500, Train Loss: 0.3173907621701558, Val Loss: 0.3275345406111549
# Epoch 40/500, Train Loss: 0.31680402318636575, Val Loss: 0.32728492337114673
# Epoch 41/500, Train Loss: 0.3160407515366872, Val Loss: 0.3269979690804201
# Epoch 42/500, Train Loss: 0.31595616738001503, Val Loss: 0.3263588284744936
# Epoch 43/500, Train Loss: 0.3156341520945231, Val Loss: 0.32605845787945914
# Epoch 44/500, Train Loss: 0.3155128320058187, Val Loss: 0.3257377621005563
# Epoch 45/500, Train Loss: 0.31458935141563416, Val Loss: 0.32522093723802004
# Epoch 46/500, Train Loss: 0.3141415154933929, Val Loss: 0.3249137752196368
# Epoch 47/500, Train Loss: 0.3137507768472036, Val Loss: 0.3244328761802
# Epoch 48/500, Train Loss: 0.31345074613889057, Val Loss: 0.3240971968454473
# Epoch 49/500, Train Loss: 0.3132074145476023, Val Loss: 0.3240058649988735
# Epoch 50/500, Train Loss: 0.31300477862358095, Val Loss: 0.3234872362192939
# Epoch 51/500, Train Loss: 0.313150353829066, Val Loss: 0.323383373372695
# Epoch 52/500, Train Loss: 0.3123037334283193, Val Loss: 0.3229586709948147
# Epoch 53/500, Train Loss: 0.31209766189257304, Val Loss: 0.3229081104783451
# Epoch 54/500, Train Loss: 0.31184346159299214, Val Loss: 0.32254409264115724
# Epoch 55/500, Train Loss: 0.31228400429089864, Val Loss: 0.32218871221822853
# Epoch 56/500, Train Loss: 0.31184759457906086, Val Loss: 0.32226132470018726
# Epoch 57/500, Train Loss: 0.3110026760896047, Val Loss: 0.32191290048991933
# Epoch 58/500, Train Loss: 0.31135171532630923, Val Loss: 0.321586738614475
# Epoch 59/500, Train Loss: 0.3110330410798391, Val Loss: 0.3211595538784476
# Epoch 60/500, Train Loss: 0.31054757316907244, Val Loss: 0.32114842884680805
# Epoch 61/500, Train Loss: 0.31040204922358194, Val Loss: 0.320797802770839
# Epoch 62/500, Train Loss: 0.309706627925237, Val Loss: 0.32092422071625204
# Epoch 63/500, Train Loss: 0.3105021619796753, Val Loss: 0.3206362794427311
# Epoch 64/500, Train Loss: 0.3095449995994568, Val Loss: 0.32051677037687865
# Epoch 65/500, Train Loss: 0.3092401019732157, Val Loss: 0.32018949705011707
# Epoch 66/500, Train Loss: 0.309410369793574, Val Loss: 0.3201551244539373
# Epoch 67/500, Train Loss: 0.309706863562266, Val Loss: 0.31996385840808644
# Epoch 68/500, Train Loss: 0.30874584158261614, Val Loss: 0.31967781571780934
# Epoch 69/500, Train Loss: 0.3090785380204519, Val Loss: 0.31957896141444936
# Epoch 70/500, Train Loss: 0.30861579775810244, Val Loss: 0.3193719159154331
# Epoch 71/500, Train Loss: 0.3088971666495005, Val Loss: 0.3191531160298516
# Epoch 72/500, Train Loss: 0.30822662353515623, Val Loss: 0.31908809612779054
# Epoch 73/500, Train Loss: 0.3083778111139933, Val Loss: 0.31895283215186176
# Epoch 74/500, Train Loss: 0.3078128151098887, Val Loss: 0.31871204691774707
# Epoch 75/500, Train Loss: 0.30825084368387856, Val Loss: 0.31855002571554747
# Epoch 76/500, Train Loss: 0.3079141783714294, Val Loss: 0.3185109408462749
# Epoch 77/500, Train Loss: 0.3076532510916392, Val Loss: 0.3183177087236853
# Epoch 78/500, Train Loss: 0.3070898044109345, Val Loss: 0.31829660429674034
# Epoch 79/500, Train Loss: 0.30769166827201844, Val Loss: 0.31797066856833067
# Epoch 80/500, Train Loss: 0.308063006401062, Val Loss: 0.31787747144699097
# Epoch 81/500, Train Loss: 0.3074897038936615, Val Loss: 0.31783295554273266
# Epoch 82/500, Train Loss: 0.30701366225878396, Val Loss: 0.31754231102326336
# Epoch 83/500, Train Loss: 0.3069840367635091, Val Loss: 0.3175949471838334
# Epoch 84/500, Train Loss: 0.30679564356803896, Val Loss: 0.31723803807707396
# Epoch 85/500, Train Loss: 0.3073118535677592, Val Loss: 0.3174046067630543
# Epoch 86/500, Train Loss: 0.306752382516861, Val Loss: 0.3173254421528648
# Epoch 87/500, Train Loss: 0.30649888157844546, Val Loss: 0.3171195159940159
# Epoch 88/500, Train Loss: 0.3067210332552592, Val Loss: 0.31698985485469594
# Epoch 89/500, Train Loss: 0.3065760465463003, Val Loss: 0.3169269535471411
# Epoch 90/500, Train Loss: 0.3061538640658061, Val Loss: 0.31684773722115683
# Epoch 91/500, Train Loss: 0.30609092036883034, Val Loss: 0.31673285803374124
# Epoch 92/500, Train Loss: 0.30574982047080995, Val Loss: 0.3166504248100169
# Epoch 93/500, Train Loss: 0.306540279785792, Val Loss: 0.3165174336994396
# Epoch 94/500, Train Loss: 0.3058929677804311, Val Loss: 0.31638382988817554
# Epoch 95/500, Train Loss: 0.3056991696357727, Val Loss: 0.3163617411080529
# Epoch 96/500, Train Loss: 0.3055513072013855, Val Loss: 0.3163595234646517
# Epoch 97/500, Train Loss: 0.3062134412924449, Val Loss: 0.3162598802762873
# Epoch 98/500, Train Loss: 0.3058452792962392, Val Loss: 0.31610143009354086
# Epoch 99/500, Train Loss: 0.3052911841869354, Val Loss: 0.31592312893446756
# Epoch 100/500, Train Loss: 0.30504613439242045, Val Loss: 0.31601174876970406
# Epoch 101/500, Train Loss: 0.3049447214603424, Val Loss: 0.31595412597936745
# Epoch 102/500, Train Loss: 0.305453949769338, Val Loss: 0.31573328901739683
# Epoch 103/500, Train Loss: 0.30499016801516216, Val Loss: 0.3159046164330314
# Epoch 104/500, Train Loss: 0.30512665073076883, Val Loss: 0.3155670569223516
# Epoch 105/500, Train Loss: 0.3047935160001119, Val Loss: 0.3156875967979431
# Epoch 106/500, Train Loss: 0.3053780468304952, Val Loss: 0.3156314939260483
# Epoch 107/500, Train Loss: 0.30506332953770954, Val Loss: 0.3154853617443758
# Epoch 108/500, Train Loss: 0.3046968495845795, Val Loss: 0.31537045976694894
# Epoch 109/500, Train Loss: 0.3048781057198842, Val Loss: 0.31531107600997477
# Epoch 110/500, Train Loss: 0.3047792832056681, Val Loss: 0.3151620863115086
# Epoch 111/500, Train Loss: 0.3047367139657338, Val Loss: 0.31515169581946206
# Epoch 112/500, Train Loss: 0.30423491438229877, Val Loss: 0.31490377468221326
# Epoch 113/500, Train Loss: 0.3040137716134389, Val Loss: 0.31506751039448905
# Epoch 114/500, Train Loss: 0.3045599639415741, Val Loss: 0.31494002482470346
# Epoch 115/500, Train Loss: 0.30431924263636273, Val Loss: 0.31491121737396016
# Epoch 116/500, Train Loss: 0.3045480604966482, Val Loss: 0.314961338744444
# Epoch 117/500, Train Loss: 0.303957922856013, Val Loss: 0.31491219208521004
# Epoch 118/500, Train Loss: 0.3043963853518168, Val Loss: 0.3147992070983438
# Epoch 119/500, Train Loss: 0.30418672879536945, Val Loss: 0.3146779800162596
# Epoch 120/500, Train Loss: 0.30387993494669596, Val Loss: 0.3146238826653537
# Epoch 121/500, Train Loss: 0.3038797930876414, Val Loss: 0.3145323080175063
# Epoch 122/500, Train Loss: 0.30395389993985494, Val Loss: 0.31441879798384276
# Epoch 123/500, Train Loss: 0.3041927929719289, Val Loss: 0.31431644804337444
# Epoch 124/500, Train Loss: 0.30381091674168903, Val Loss: 0.3141269035199109
# Epoch 125/500, Train Loss: 0.30360716780026753, Val Loss: 0.3142021517543232
# Epoch 126/500, Train Loss: 0.3038662401835124, Val Loss: 0.31422871175934286
# Epoch 127/500, Train Loss: 0.30344169060389203, Val Loss: 0.3141307480194989
# Epoch 128/500, Train Loss: 0.3038224267959595, Val Loss: 0.3139897619976717
# Epoch 129/500, Train Loss: 0.30311356743176776, Val Loss: 0.3139743112465915
# Epoch 130/500, Train Loss: 0.3032683265209198, Val Loss: 0.3139295674422208
# Epoch 131/500, Train Loss: 0.3033259499073029, Val Loss: 0.31384966040358825
# Epoch 132/500, Train Loss: 0.30295454819997153, Val Loss: 0.3138206767685273
# Epoch 133/500, Train Loss: 0.30320769707361855, Val Loss: 0.31371266526334424
# Epoch 134/500, Train Loss: 0.3023919234673182, Val Loss: 0.3137354123241761
# Epoch 135/500, Train Loss: 0.3036757242679596, Val Loss: 0.3136027621872285
# Epoch 136/500, Train Loss: 0.30294253428777057, Val Loss: 0.3135351731496699
# Epoch 137/500, Train Loss: 0.302793390750885, Val Loss: 0.3136041813036975
# Epoch 138/500, Train Loss: 0.3033024434248606, Val Loss: 0.31363918500788074
# Epoch 139/500, Train Loss: 0.3028427171707153, Val Loss: 0.3134336243657505
# Epoch 140/500, Train Loss: 0.3027290940284729, Val Loss: 0.31352173317881193
# Epoch 141/500, Train Loss: 0.3023637596766154, Val Loss: 0.3133746245328118
# Epoch 142/500, Train Loss: 0.30299035747845965, Val Loss: 0.31329748911016125
# Epoch 143/500, Train Loss: 0.30250539382298786, Val Loss: 0.3133384322418886
# Epoch 144/500, Train Loss: 0.30242969751358034, Val Loss: 0.31310299126540914
# Epoch 145/500, Train Loss: 0.30211012363433837, Val Loss: 0.312984906575259
# Epoch 146/500, Train Loss: 0.30245619535446167, Val Loss: 0.3130731521283879
# Epoch 147/500, Train Loss: 0.3023996110757192, Val Loss: 0.31315825265996594
# Epoch 148/500, Train Loss: 0.3018348815043767, Val Loss: 0.3130626082420349
# Epoch 149/500, Train Loss: 0.30187222679456077, Val Loss: 0.31305011055048776
# Epoch 150/500, Train Loss: 0.3018698453903198, Val Loss: 0.31302083765759187
# Epoch 151/500, Train Loss: 0.3023326373100281, Val Loss: 0.3128441738731721
# Epoch 152/500, Train Loss: 0.30238146622975665, Val Loss: 0.3129466281217687
# Epoch 153/500, Train Loss: 0.3020634432633718, Val Loss: 0.31273437598172354
# Epoch 154/500, Train Loss: 0.30230635285377505, Val Loss: 0.31259052192463593
# Epoch 155/500, Train Loss: 0.3021555765469869, Val Loss: 0.31273556895115795
# Epoch 156/500, Train Loss: 0.30184812426567076, Val Loss: 0.3125470008920221
# Epoch 157/500, Train Loss: 0.30165383537610374, Val Loss: 0.3127414636752185
# Epoch 158/500, Train Loss: 0.3020721546808879, Val Loss: 0.31256168905426474
# Epoch 159/500, Train Loss: 0.3016008412837982, Val Loss: 0.3124966314610313
# Epoch 160/500, Train Loss: 0.3019870960712433, Val Loss: 0.3123451962190516
# Epoch 161/500, Train Loss: 0.30127323150634766, Val Loss: 0.31239732311052437
# Epoch 162/500, Train Loss: 0.3020019785563151, Val Loss: 0.3124561879564734
# Epoch 163/500, Train Loss: 0.30172298232714334, Val Loss: 0.3124266643734539
# Epoch 164/500, Train Loss: 0.3016175385316213, Val Loss: 0.31234581505551057
# Epoch 165/500, Train Loss: 0.3023982377847036, Val Loss: 0.3124445615445866
# Epoch 166/500, Train Loss: 0.3013122844696045, Val Loss: 0.31226250704597025
# Epoch 167/500, Train Loss: 0.30145458738009134, Val Loss: 0.3123389210771112
# Epoch 168/500, Train Loss: 0.30138482610384626, Val Loss: 0.3123299356769113
# Epoch 169/500, Train Loss: 0.3015171047051748, Val Loss: 0.312279578517465
# Epoch 170/500, Train Loss: 0.30121776700019837, Val Loss: 0.3121723769342198
# Epoch 171/500, Train Loss: 0.30101254224777224, Val Loss: 0.31213093242224527
# Epoch 172/500, Train Loss: 0.30192553798357646, Val Loss: 0.3122327546862995
# Epoch 173/500, Train Loss: 0.30226855794588725, Val Loss: 0.3119767676381504
# Epoch 174/500, Train Loss: 0.3011455194155375, Val Loss: 0.31203367955544414
# Epoch 175/500, Train Loss: 0.30072821060816446, Val Loss: 0.3119792096755084
# Epoch 176/500, Train Loss: 0.30114407181739805, Val Loss: 0.3120937969754724
# Epoch 177/500, Train Loss: 0.3005926366647085, Val Loss: 0.3119972874136532
# Epoch 178/500, Train Loss: 0.30121475338935855, Val Loss: 0.31200244935119853
# Epoch 179/500, Train Loss: 0.3016776200135549, Val Loss: 0.3119499455480015
# Epoch 180/500, Train Loss: 0.30154009620348615, Val Loss: 0.3116864272776772
# Epoch 181/500, Train Loss: 0.3009887699286143, Val Loss: 0.31172627210617065
# Epoch 182/500, Train Loss: 0.30044764240582783, Val Loss: 0.3118549997315687
# Epoch 183/500, Train Loss: 0.30034602761268614, Val Loss: 0.31181007185403037
# Epoch 184/500, Train Loss: 0.3006280048688253, Val Loss: 0.31179401979726906
# Epoch 185/500, Train Loss: 0.3012148769696554, Val Loss: 0.3118241630932864
# Epoch 186/500, Train Loss: 0.30120648741722106, Val Loss: 0.31165823428069844
# Epoch 187/500, Train Loss: 0.3006740876038869, Val Loss: 0.3117428930366741
# Epoch 188/500, Train Loss: 0.30138578097025553, Val Loss: 0.311717029003536
# Epoch 189/500, Train Loss: 0.3006142787138621, Val Loss: 0.31158384768401876
# Epoch 190/500, Train Loss: 0.30009673337141674, Val Loss: 0.3115251073065926
# Epoch 191/500, Train Loss: 0.3010723602771759, Val Loss: 0.31171176801709566
# Epoch 192/500, Train Loss: 0.3002575083573659, Val Loss: 0.31151558458805084
# Epoch 193/500, Train Loss: 0.30044888536135356, Val Loss: 0.31150786140385794
# Epoch 194/500, Train Loss: 0.3007990558942159, Val Loss: 0.31153891279416923
# Epoch 195/500, Train Loss: 0.30089246153831484, Val Loss: 0.3114859330303529
# Epoch 196/500, Train Loss: 0.30087826212247215, Val Loss: 0.31135499302078695
# Epoch 197/500, Train Loss: 0.30043891588846844, Val Loss: 0.3114120276535259
# Epoch 198/500, Train Loss: 0.3007427167892456, Val Loss: 0.311399387086139
# Epoch 199/500, Train Loss: 0.3008635155359904, Val Loss: 0.3111741139608271
# Epoch 200/500, Train Loss: 0.3001974864800771, Val Loss: 0.31130942789947286
# Epoch 201/500, Train Loss: 0.3005773170789083, Val Loss: 0.3110368356985204
# Epoch 202/500, Train Loss: 0.2999819664160411, Val Loss: 0.3111588420236812
# Epoch 203/500, Train Loss: 0.30085084756215413, Val Loss: 0.31105030547170076
# Epoch 204/500, Train Loss: 0.30023521184921265, Val Loss: 0.3111656974343693
# Epoch 205/500, Train Loss: 0.2997875237464905, Val Loss: 0.31104859972701354
# Epoch 206/500, Train Loss: 0.30044342557589215, Val Loss: 0.3110322514001061
# Epoch 207/500, Train Loss: 0.2999237513542175, Val Loss: 0.3110846123274635
# Epoch 208/500, Train Loss: 0.30057628472646075, Val Loss: 0.3109922987573287
# Epoch 209/500, Train Loss: 0.2998275446891785, Val Loss: 0.3109510427012163
# Epoch 210/500, Train Loss: 0.3001524984836578, Val Loss: 0.31094980590483723
# Early stopping triggered.
# Autoencoder training completed
# Saved unnormalized autoencoder at /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background/l1_bg_autoencoder_layer_fc2_seed_1111111.pth
#
# All autoencoders trained and saved successfully.

# %% [markdown]
# ### Load the saved SAE and project

# %%
# Load the pre-trained autoencoder for layer 6 (fc2) (from snippet 4)
def load_autoencoder(device, save_sae_dir):
    """
    Load a pre-trained sparse autoencoder and freeze its parameters.
    """
    input_dims = 4096
    encoding_dim = 16000

    # Initialize the autoencoder
    autoencoder = SparseAutoencoder(input_dims, encoding_dim)
    autoencoder.load_state_dict(torch.load(save_sae_dir))  # Load weights
    autoencoder = autoencoder.to(device)  # Move model to device

    # Freeze all parameters of the autoencoder
    for param in autoencoder.parameters():
        param.requires_grad = False

    # Set the autoencoder to evaluation mode
    autoencoder.eval()
    print(f"Autoencoder loaded from {save_sae_dir} and frozen successfully.")
    return autoencoder



####################

def load_model(saved_weights_path, device):
    """
    Loads a trained PyTorch AlexNet model, freezes all layers up to fc2,
    and prepares it for passing activations through classifier[5] and classifier[6].

    Args:
        saved_weights_path (str): Path to the saved weights of the trained AlexNet model.
        device (torch.device): The device to load the model onto (e.g., torch.device('cuda') or torch.device('cpu')).

    Returns:
        torch.nn.Module: The loaded and partially frozen PyTorch AlexNet model.
    """
    # Load the PyTorch AlexNet model
    print(f"Loading model from {saved_weights_path}")
    model = models.alexnet(pretrained=False)  # Load AlexNet without pretrained weights
    model.classifier[-1] = nn.Linear(4096, 2)  # Update the last layer for binary classification

    # Load the saved weights
    model.load_state_dict(torch.load(saved_weights_path, map_location=device))
    model.to(device)

    # Freeze all layers except `classifier[5]` (ReLU) and `classifier[6]` (fc3)
    for name, param in model.named_parameters():
        if name.startswith("classifier.6"):  # classifier[6] corresponds to fc3
            param.requires_grad = True
        elif name.startswith("classifier.5"):  # ReLU does not have trainable params
            param.requires_grad = True
        else:
            param.requires_grad = False

    # Set the model to evaluation mode
    model.eval()
    print("Model loaded and all layers up to fc2 are frozen")
    return model

# %%
from pathlib import Path

base_dir = "/content/drive/MyDrive/Masterthesis/Datasets/mnist"
activation_dir = os.path.join(base_dir, "activations")
output_base_dir = os.path.join(base_dir, "outputs")
Path(output_base_dir).mkdir(parents=True, exist_ok=True)



# Define paths for pre-saved activations
def get_activation_path(folder_name, filename):
    return os.path.join(activation_dir, folder_name, f"{filename}.npy")


def extract_fc2_activations(model, dataloader):
    """
    Extract activations from the fc2 layer (classifier[4]) of the PyTorch AlexNet.
    Args:
        model: Pretrained or fine-tuned PyTorch AlexNet model.
        dataloader: DataLoader for the test set.

    Returns:
        numpy.ndarray: Activations from fc2 for all images in the dataloader.
    """
    print("Extracting AlexNet activations for layer fc2...")
    activations = []

    # Ensure the model is in evaluation mode
    model.eval()

    with torch.no_grad():  # Disable gradient computation
        for batch_idx, (image_tensor, _) in enumerate(dataloader):  # Expect only 2 elements: (img, is_two)
            # Move image tensor to the device (CPU or GPU)
            image_tensor = image_tensor.to(device)

            # Pass through the feature extractor
            features = model.features(image_tensor)
            features = model.avgpool(features)  # Apply average pooling
            features = torch.flatten(features, 1)  # Flatten for classifier input

            # Pass through classifier layers up to fc2
            for idx, layer in enumerate(model.classifier):
                features = layer(features)
                if idx == 4:  # Stop after fc2 (classifier[4])
                    activations.append(features.cpu().numpy())
                    break

            # Log progress
            if (batch_idx + 1) % 10 == 0:
                print(f"Processed {batch_idx + 1}/{len(dataloader)} batches")

            # Clear resources
            torch.cuda.empty_cache()
            gc.collect()

    # Stack activations into a single array
    return np.vstack(activations)




def load_or_extract_fc2_activations(model, dataloader, folder_name, filename):
    # Generate activation file path
    activation_path = get_activation_path(folder_name, filename)

    # Check if the activation file exists
    if os.path.exists(activation_path):
        print(f"Loading pre-saved AlexNet activations for {filename} from {activation_path}...")
        activations = np.load(activation_path, allow_pickle=True)
    else:
        print(f"No pre-saved AlexNet activations found for {filename}. Extracting and saving...")
        activations = extract_fc2_activations(model, dataloader)  # Extract activations
        os.makedirs(os.path.dirname(activation_path), exist_ok=True)  # Ensure directory exists
        np.save(activation_path, activations)  # Save activations
        print(f"Activations for layer fc2 saved to {activation_path}")

    return activations

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def load_model(model_path, freeze_layers=True, pretrained=False):
    """
    Loads an AlexNet model, updates it for binary classification, and optionally freezes layers.

    Args:
        model_path (str): Path to the saved model weights.
        freeze_layers (bool): Whether to freeze all layers except the classifier.
        pretrained (bool): Whether to use pretrained weights (e.g., from ImageNet) for initialization.

    Returns:
        model: The loaded and configured AlexNet model.
    """
    print(f"Loading model from {model_path}")
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load AlexNet with or without pretrained weights
    model = models.alexnet(pretrained=pretrained)
    model.classifier[-1] = nn.Linear(4096, 2)  # Update the final layer for binary classification

    # Load saved weights
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    model.eval()  # Set the model to evaluation mode
    print("Model loaded successfully")

    # Optionally freeze all layers
    if freeze_layers:
        for param in model.parameters():
            param.requires_grad = False
        print("All layers frozen successfully")

    return model

def attach_fc2_hook(model):
    """
    Attaches a forward hook to capture activations from fc2.

    Args:
        model: The model to attach the hook to.

    Returns:
        activations (dict): A dictionary to store captured activations.
    """
    activations = {"fc2": []}  # Use a list to accumulate activations

    def hook(module, input, output):
        activations["fc2"].append(output.cpu().numpy())  # Append activations

    model.classifier[4].register_forward_hook(hook)
    print("Hook attached to fc2 successfully")
    return activations


    return activations

# %%
from sklearn.metrics import accuracy_score

def main():
    # Paths and initialization
    model_paths = [
        #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1.pt",
        #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_11.pt",
        #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_111.pt",
        #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1111.pt",
        #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_11111.pt",
        #"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_111111.pt",
        "/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1111111.pt"
    ]

    # Define dataset paths
    dataset_paths = {
        "test_two_bg_100": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/test/class_2_100',
        "test_two_org_100": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/test/class_2_100',
        "test_zero_bg_100": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/test/class_0_100',
        "test_zero_org_100": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/test/class_0_100',
        "val_zero_org_200": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/val/class_0_200',
        "val_zero_org_100": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/val/class_0_100',
        "val_zero_org_50": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/val/class_0_50',
        "val_zero_org_25": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/val/class_0_25',
        "val_zero_bg_200": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0_200',
        "val_zero_bg_100": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0_100',
        "val_zero_bg_50": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0_50',
        "val_zero_bg_25": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/val/class_0_25',


        #"val_zero_fg": '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/foreground/val/class_0'
    }
    # Prepare dataloaders
    dataloaders = {}
    for key, folder in dataset_paths.items():
        image_paths = [
            os.path.join(root, file)
            for root, dirs, files in os.walk(folder)
            for file in files if file.endswith(('.jpg', '.png'))
        ]
        # Use is_two = 1 if "two" is in the key, else 0
        dataset = MnistDataset(data_files=image_paths, is_two=1 if "two" in key else 0)
        dataloaders[key] = DataLoader(dataset, batch_size=1, shuffle=False)

    # Directory for saving results
    sparse_output_dir = "/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background"
    os.makedirs(sparse_output_dir, exist_ok=True)

    # Loop over models
    for model_path in model_paths:
        print(f"Processing model: {model_path}")

        # Load the model
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = load_model(model_path, device)
        activations_dict = attach_fc2_hook(model)  # Attach the hook for fc2 activations


        # Process each dataset
        for key, loader in dataloaders.items():
            print(f"Processing dataset: {key}")

            # Reinitialize activations_dict["fc2"] for each dataset
            activations_dict["fc2"] = []  # Reset fc2 activations
            # Extract activations
            activations = load_or_extract_fc2_activations(
                model, loader, f'{key}_{Path(model_path).stem}', f'bg_fc2_activations_{key}_{Path(model_path).stem}'
            )

            # Save activations
            activation_path = os.path.join(sparse_output_dir, f"fc2_activations_{key}_{Path(model_path).stem}.npy")
            np.save(activation_path, activations)
            print(f"Activations for {key} saved to: {activation_path}")
            # Clear activations for the next dataset
            activations_dict["fc2"] = None
#main()
# Out:
# Processing model: /content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1111111.pt
# Loading model from /content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1111111.pt
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# <ipython-input-17-72707b08f62e>:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Model loaded successfully
# All layers frozen successfully
# Hook attached to fc2 successfully
# Processing dataset: test_two_bg_100
# No pre-saved AlexNet activations found for bg_fc2_activations_test_two_bg_100_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/100 batches
# Processed 20/100 batches
# Processed 30/100 batches
# Processed 40/100 batches
# Processed 50/100 batches
# Processed 60/100 batches
# Processed 70/100 batches
# Processed 80/100 batches
# Processed 90/100 batches
# Processed 100/100 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/test_two_bg_100_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_test_two_bg_100_alexnet_mnist_bg_seed_1111111.npy
# Activations for test_two_bg_100 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_bg_100_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: test_two_org_100
# No pre-saved AlexNet activations found for bg_fc2_activations_test_two_org_100_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/100 batches
# Processed 20/100 batches
# Processed 30/100 batches
# Processed 40/100 batches
# Processed 50/100 batches
# Processed 60/100 batches
# Processed 70/100 batches
# Processed 80/100 batches
# Processed 90/100 batches
# Processed 100/100 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/test_two_org_100_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_test_two_org_100_alexnet_mnist_bg_seed_1111111.npy
# Activations for test_two_org_100 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_org_100_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: test_zero_bg_100
# No pre-saved AlexNet activations found for bg_fc2_activations_test_zero_bg_100_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/100 batches
# Processed 20/100 batches
# Processed 30/100 batches
# Processed 40/100 batches
# Processed 50/100 batches
# Processed 60/100 batches
# Processed 70/100 batches
# Processed 80/100 batches
# Processed 90/100 batches
# Processed 100/100 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/test_zero_bg_100_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_test_zero_bg_100_alexnet_mnist_bg_seed_1111111.npy
# Activations for test_zero_bg_100 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_bg_100_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: test_zero_org_100
# No pre-saved AlexNet activations found for bg_fc2_activations_test_zero_org_100_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/100 batches
# Processed 20/100 batches
# Processed 30/100 batches
# Processed 40/100 batches
# Processed 50/100 batches
# Processed 60/100 batches
# Processed 70/100 batches
# Processed 80/100 batches
# Processed 90/100 batches
# Processed 100/100 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/test_zero_org_100_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_test_zero_org_100_alexnet_mnist_bg_seed_1111111.npy
# Activations for test_zero_org_100 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_org_100_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: val_zero_org_200
# No pre-saved AlexNet activations found for bg_fc2_activations_val_zero_org_200_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/200 batches
# Processed 20/200 batches
# Processed 30/200 batches
# Processed 40/200 batches
# Processed 50/200 batches
# Processed 60/200 batches
# Processed 70/200 batches
# Processed 80/200 batches
# Processed 90/200 batches
# Processed 100/200 batches
# Processed 110/200 batches
# Processed 120/200 batches
# Processed 130/200 batches
# Processed 140/200 batches
# Processed 150/200 batches
# Processed 160/200 batches
# Processed 170/200 batches
# Processed 180/200 batches
# Processed 190/200 batches
# Processed 200/200 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/val_zero_org_200_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_val_zero_org_200_alexnet_mnist_bg_seed_1111111.npy
# Activations for val_zero_org_200 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_org_200_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: val_zero_org_100
# No pre-saved AlexNet activations found for bg_fc2_activations_val_zero_org_100_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/100 batches
# Processed 20/100 batches
# Processed 30/100 batches
# Processed 40/100 batches
# Processed 50/100 batches
# Processed 60/100 batches
# Processed 70/100 batches
# Processed 80/100 batches
# Processed 90/100 batches
# Processed 100/100 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/val_zero_org_100_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_val_zero_org_100_alexnet_mnist_bg_seed_1111111.npy
# Activations for val_zero_org_100 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_org_100_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: val_zero_org_50
# No pre-saved AlexNet activations found for bg_fc2_activations_val_zero_org_50_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/50 batches
# Processed 20/50 batches
# Processed 30/50 batches
# Processed 40/50 batches
# Processed 50/50 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/val_zero_org_50_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_val_zero_org_50_alexnet_mnist_bg_seed_1111111.npy
# Activations for val_zero_org_50 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_org_50_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: val_zero_org_25
# No pre-saved AlexNet activations found for bg_fc2_activations_val_zero_org_25_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/25 batches
# Processed 20/25 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/val_zero_org_25_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_val_zero_org_25_alexnet_mnist_bg_seed_1111111.npy
# Activations for val_zero_org_25 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_org_25_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: val_zero_bg_200
# No pre-saved AlexNet activations found for bg_fc2_activations_val_zero_bg_200_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/200 batches
# Processed 20/200 batches
# Processed 30/200 batches
# Processed 40/200 batches
# Processed 50/200 batches
# Processed 60/200 batches
# Processed 70/200 batches
# Processed 80/200 batches
# Processed 90/200 batches
# Processed 100/200 batches
# Processed 110/200 batches
# Processed 120/200 batches
# Processed 130/200 batches
# Processed 140/200 batches
# Processed 150/200 batches
# Processed 160/200 batches
# Processed 170/200 batches
# Processed 180/200 batches
# Processed 190/200 batches
# Processed 200/200 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/val_zero_bg_200_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_val_zero_bg_200_alexnet_mnist_bg_seed_1111111.npy
# Activations for val_zero_bg_200 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_bg_200_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: val_zero_bg_100
# No pre-saved AlexNet activations found for bg_fc2_activations_val_zero_bg_100_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/100 batches
# Processed 20/100 batches
# Processed 30/100 batches
# Processed 40/100 batches
# Processed 50/100 batches
# Processed 60/100 batches
# Processed 70/100 batches
# Processed 80/100 batches
# Processed 90/100 batches
# Processed 100/100 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/val_zero_bg_100_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_val_zero_bg_100_alexnet_mnist_bg_seed_1111111.npy
# Activations for val_zero_bg_100 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_bg_100_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: val_zero_bg_50
# No pre-saved AlexNet activations found for bg_fc2_activations_val_zero_bg_50_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/50 batches
# Processed 20/50 batches
# Processed 30/50 batches
# Processed 40/50 batches
# Processed 50/50 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/val_zero_bg_50_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_val_zero_bg_50_alexnet_mnist_bg_seed_1111111.npy
# Activations for val_zero_bg_50 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_bg_50_alexnet_mnist_bg_seed_1111111.npy
# Processing dataset: val_zero_bg_25
# No pre-saved AlexNet activations found for bg_fc2_activations_val_zero_bg_25_alexnet_mnist_bg_seed_1111111. Extracting and saving...
# Extracting AlexNet activations for layer fc2...
# Processed 10/25 batches
# Processed 20/25 batches
# Activations for layer fc2 saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/val_zero_bg_25_alexnet_mnist_bg_seed_1111111/bg_fc2_activations_val_zero_bg_25_alexnet_mnist_bg_seed_1111111.npy
# Activations for val_zero_bg_25 saved to: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_bg_25_alexnet_mnist_bg_seed_1111111.npy

# %% [markdown]
# continue starting from here

# %% [markdown]
# ### 200

# %%
from sklearn.metrics import accuracy_score
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Function 12 to classify decoded activations
def classify_decoded_activations(model, decoded_activations):
    """Classify decoded activations using the softmax layer of the model."""
    predictions = []
    for activation in decoded_activations:
        # Convert numpy activation to a tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)

        # Pass through classifier[5] (ReLU)
        relu_output = model.classifier[5](activation_tensor)

        # Pass through classifier[6] (final linear layer)
        output = model.classifier[6](relu_output)

        # Apply softmax and get the predicted class
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)

    return predictions

# Function to calculate and plot correlation histograms
def plot_correlation_histogram(original, projected, title):
    correlations = [
        np.corrcoef(original[:, i], projected[:, i])[0, 1]
        if np.std(original[:, i]) > 0 and np.std(projected[:, i]) > 0
        else 0  # Handle constant features
        for i in range(original.shape[1])
    ]
    correlations = np.nan_to_num(correlations)  # Replace NaNs with 0
    plt.hist(correlations, bins=50, alpha=0.7)
    plt.title(title)
    plt.xlabel("Correlation")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

# Project activations into sparse space
def project_activations(autoencoder, activations, device):
    print("Projecting Alexnet activations into SAE sparse space...")
    with torch.no_grad():
        projected = autoencoder.encoder(torch.from_numpy(activations).to(device).float())
    return projected.cpu().numpy()

# Save all neuron differences and indexes in descending order
def save_all_neurons_to_csv(abs_diff, folder_name, filename="all_neuron_differences_200.csv"):
    """
    Save all neuron indexes sorted by their differences (descending order) to a CSV file.
    """
    print(f"Saving all neuron differences to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

    return csv_path # return the csv_path


def save_neurons_by_correlation(val_patch_activations, val_no_patch_activations, folder_name, filename="neurons_by_correlation_200.csv"):
    os.makedirs(folder_name, exist_ok=True)

    # Number of neurons should be 16k
    num_neurons = val_patch_activations.shape[1]
    print(f"Number of val patch neurons: {num_neurons}")
    num_images = val_patch_activations.shape[0]
    print(f"Number of val patch images: {val_patch_activations.shape[0]}")

    # Create a binary label vector pp (1 for patch, 0 for no patch)
    pp = np.concatenate([np.ones(val_patch_activations.shape[0]), np.zeros(val_no_patch_activations.shape[0])])
    print(f"Number of pp labels: {len(pp)}")

    # array to store correlations
    correlations = np.zeros(num_neurons)

    for i in range(num_neurons):
        # Combine activations for neuron i from both datassets p and np
        act_i = np.concatenate([val_patch_activations[:, i], val_no_patch_activations[:, i]])

        # Compute correlation between pp and act_i
        if np.std(pp) > 0 and np.std(act_i) > 0:
            corr = np.corrcoef(pp, act_i)[0, 1]
        else:
            corr = 0  # Handle constant vectors

        correlations[i] = corr

    # As previous code
    # Handle NaN correlations (replace NaN with 0)
    correlations = np.nan_to_num(correlations)
    print('shape of correlations', correlations.shape)

    # Create a DataFrame with neuron indices and their correlations
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(num_neurons),
        "Correlation": correlations
    })

    # Sort by correlation in descending order
    neuron_data.sort_values(by="Correlation", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"Neuron correlations saved at: {csv_path}")

    return csv_path

def save_top_neurons_to_csv(abs_diff, top_neurons, folder_name, filename="bg_top_neurons_200.csv"):
    """
    Save the top neurons with their difference values to a CSV file.
    """
    print(f"Saving top neurons to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": range(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Mark whether each neuron is in the top 10%
    neuron_data["Selected_for_Muting"] = neuron_data["Neuron_Index"].isin(top_neurons)

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

# Function to load top neurons from CSV based on a percentage
def load_top_neurons_from_csv(folder_name, filename, percentage):
    """
    Load top neurons based on the specified percentage from the saved CSV file.
    """
    csv_path = os.path.join(folder_name, filename)
    neuron_data = pd.read_csv(csv_path)

    # Calculate the number of top neurons to select
    top_count = int(len(neuron_data) * (percentage / 100))

    # Select the top neurons based on their activation difference
    top_neurons = neuron_data.iloc[:top_count]["Neuron_Index"].values
    print(f"Loaded top {percentage}% neurons ({top_count} neurons) for muting.")
    return top_neurons


def classify_with_alexnet(model, activations):
    """
    Classify images using the original AlexNet classifier on the fc2 activations.
    """
    predictions = []
    for activation in activations:
        # Convert numpy activation to tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)
        relu_output = model.classifier[5](activation_tensor)  # Apply ReLU
        output = model.classifier[6](relu_output)  # Apply fc3
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)
    return predictions

# Function to calculate accuracy per group
def calculate_group_accuracy(predictions, true_labels):
    return accuracy_score(true_labels, predictions)


def main():
    import pandas as pd
    import os
    import numpy as np
    import torch

    seeds = [1, 11, 111, 1111, 11111, 111111, 1111111] #!!!!!

    # Paths to models, activations, and autoencoders for each seed
    model_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_{seed}.pt"
        for seed in seeds
    ]
    autoencoder_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background/l1_bg_autoencoder_layer_fc2_seed_{seed}.pth"
        for seed in seeds
    ]
    test_activation_two_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_two_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_bg_200_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_org_200_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]

    # Output folder for results
    folder_name = "/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background"
    os.makedirs(folder_name, exist_ok=True)

    # Prepare a DataFrame to store results
    results_df = pd.DataFrame(columns=[
        "Seed", "Percentage",
        "Val_Patch_Before", "Val_NoPatch_Before",
        "Val_Patch_After", "Val_NoPatch_After",
        "Test_Two_Patch_Before", "Test_Two_NoPatch_Before",
        "Test_Two_Patch_After", "Test_Two_NoPatch_After",
        "Test_Zero_Patch_Before", "Test_Zero_NoPatch_Before",
        "Test_Zero_Patch_After", "Test_Zero_NoPatch_After",
        "Worst_Acc_Before", "Worst_Acc_After",
        "Avg_Acc_Before", "Avg_Acc_After"
    ])

    # Loop through seeds/models/autoencoders
    for seed_idx, seed in enumerate(seeds):
        print(f"\nProcessing Seed {seed}")

        # Load paths
        model_path = model_paths[seed_idx]
        sae_path = autoencoder_paths[seed_idx]
        val_patch_path = val_activation_patch_paths[seed_idx]
        val_no_patch_path = val_activation_no_patch_paths[seed_idx]
        test_two_patch_path = test_activation_two_patch_paths[seed_idx]
        test_two_no_patch_path = test_activation_two_no_patch_paths[seed_idx]
        test_zero_patch_path = test_activation_zero_patch_paths[seed_idx]
        test_zero_no_patch_path = test_activation_zero_no_patch_paths[seed_idx]

        # Load the model and autoencoder
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = load_model(model_path, device)
        autoencoder = load_autoencoder(device, sae_path)

        # Load pre-saved activations
        val_activations_patch = np.load(val_patch_path, allow_pickle=True)
        val_activations_no_patch = np.load(val_no_patch_path, allow_pickle=True)

        test_two_patch = np.load(test_two_patch_path, allow_pickle=True)
        test_two_no_patch = np.load(test_two_no_patch_path, allow_pickle=True)
        test_zero_patch = np.load(test_zero_patch_path, allow_pickle=True)
        test_zero_no_patch = np.load(test_zero_no_patch_path, allow_pickle=True)

        # Classify "before muting"
        predictions_val_patch_before = classify_with_alexnet(model, val_activations_patch)
        predictions_val_no_patch_before = classify_with_alexnet(model, val_activations_no_patch)
        accuracy_val_patch_before = calculate_group_accuracy(predictions_val_patch_before, [0] * len(predictions_val_patch_before))
        accuracy_val_no_patch_before = calculate_group_accuracy(predictions_val_no_patch_before, [0] * len(predictions_val_no_patch_before))

        predictions_test_two_patch_before = classify_with_alexnet(model, test_two_patch)
        predictions_test_two_no_patch_before = classify_with_alexnet(model, test_two_no_patch)
        predictions_test_zero_patch_before = classify_with_alexnet(model, test_zero_patch)
        predictions_test_zero_no_patch_before = classify_with_alexnet(model, test_zero_no_patch)

        accuracy_test_two_patch_before = calculate_group_accuracy(predictions_test_two_patch_before, [1] * len(predictions_test_two_patch_before))
        accuracy_test_two_no_patch_before = calculate_group_accuracy(predictions_test_two_no_patch_before, [1] * len(predictions_test_two_no_patch_before))
        accuracy_test_zero_patch_before = calculate_group_accuracy(predictions_test_zero_patch_before, [0] * len(predictions_test_zero_patch_before))
        accuracy_test_zero_no_patch_before = calculate_group_accuracy(predictions_test_zero_no_patch_before, [0] * len(predictions_test_zero_no_patch_before))

        # Project activations
        projected_val_patch = project_activations(autoencoder, val_activations_patch, device)
        projected_val_no_patch = project_activations(autoencoder, val_activations_no_patch, device)
        projected_two_test_patch = project_activations(autoencoder, test_two_patch, device)
        projected_two_test_no_patch = project_activations(autoencoder, test_two_no_patch, device)
        projected_zero_test_patch = project_activations(autoencoder, test_zero_patch, device)
        projected_zero_test_no_patch = project_activations(autoencoder, test_zero_no_patch, device)



        # Loop through percentages
        for percentage in range(0, 51):  # 1% to 15%
            print(f"Testing with {percentage}% muting...")

            # Calculate differences and load top neurons
            #abs_diff = np.abs(np.mean(projected_val_patch, axis=0) - np.mean(projected_val_no_patch, axis=0))
            #csv_path = save_all_neurons_to_csv(abs_diff, folder_name, filename=f"mnist_bg_val_neuron_differences_seed_{seed}.csv")
            #top_neurons = load_top_neurons_from_csv(folder_name, f"mnist_bg_val_neuron_differences_seed_{seed}.csv", percentage)


            # **Correlation-Based Neurons**
            correlation_csv_path = save_neurons_by_correlation(
                projected_val_patch, projected_val_no_patch, folder_name, filename=f"l1_neurons_by_correlation_seed_{seed}_200.csv"
            )
            top_neurons_corr = load_top_neurons_from_csv(folder_name, f"l1_neurons_by_correlation_seed_{seed}_200.csv", percentage)

            top_neurons = top_neurons_corr

            # Muting neurons
            projected_val_patch_muted = projected_val_patch.copy()
            projected_val_no_patch_muted = projected_val_no_patch.copy()
            projected_two_test_patch_muted = projected_two_test_patch.copy()
            projected_two_test_no_patch_muted = projected_two_test_no_patch.copy()
            projected_zero_test_patch_muted = projected_zero_test_patch.copy()
            projected_zero_test_no_patch_muted = projected_zero_test_no_patch.copy()

            projected_val_patch_muted[:, top_neurons] = 0
            projected_val_no_patch_muted[:, top_neurons] = 0
            projected_two_test_patch_muted[:, top_neurons] = 0
            projected_two_test_no_patch_muted[:, top_neurons] = 0
            projected_zero_test_patch_muted[:, top_neurons] = 0
            projected_zero_test_no_patch_muted[:, top_neurons] = 0

            # Decode and classify
            decoded_val_patch = autoencoder.decoder(torch.from_numpy(projected_val_patch_muted).to(device).float()).cpu().numpy()
            decoded_val_no_patch = autoencoder.decoder(torch.from_numpy(projected_val_no_patch_muted).to(device).float()).cpu().numpy()
            decoded_two_test_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_patch_muted).to(device).float()).cpu().numpy()
            decoded_two_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_no_patch_muted).to(device).float()).cpu().numpy()
            decoded_zero_test_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_patch_muted).to(device).float()).cpu().numpy()
            decoded_zero_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_no_patch_muted).to(device).float()).cpu().numpy()

            predictions_val_patch_after = classify_decoded_activations(model, decoded_val_patch)
            predictions_val_no_patch_after = classify_decoded_activations(model, decoded_val_no_patch)
            predictions_test_two_patch_after = classify_decoded_activations(model, decoded_two_test_patch)
            predictions_test_two_no_patch_after = classify_decoded_activations(model, decoded_two_test_no_patch)
            predictions_test_zero_patch_after = classify_decoded_activations(model, decoded_zero_test_patch)
            predictions_test_zero_no_patch_after = classify_decoded_activations(model, decoded_zero_test_no_patch)

            accuracy_val_patch_after = calculate_group_accuracy(predictions_val_patch_after, [0] * len(predictions_val_patch_after))
            accuracy_val_no_patch_after = calculate_group_accuracy(predictions_val_no_patch_after, [0] * len(predictions_val_no_patch_after))
            accuracy_test_two_patch_after = calculate_group_accuracy(predictions_test_two_patch_after, [1] * len(predictions_test_two_patch_after))
            accuracy_test_two_no_patch_after = calculate_group_accuracy(predictions_test_two_no_patch_after, [1] * len(predictions_test_two_no_patch_after))
            accuracy_test_zero_patch_after = calculate_group_accuracy(predictions_test_zero_patch_after, [0] * len(predictions_test_zero_patch_after))
            accuracy_test_zero_no_patch_after = calculate_group_accuracy(predictions_test_zero_no_patch_after, [0] * len(predictions_test_zero_no_patch_after))

            # Calculate worst and average group accuracies
            worst_acc_before = min(accuracy_test_two_patch_before, accuracy_test_two_no_patch_before)
            worst_acc_after = min(accuracy_test_two_patch_after, accuracy_test_two_no_patch_after)
            avg_acc_before = (accuracy_test_two_patch_before + accuracy_test_two_no_patch_before +
                              accuracy_test_zero_patch_before + accuracy_test_zero_no_patch_before) / 4
            avg_acc_after = (accuracy_test_two_patch_after + accuracy_test_two_no_patch_after +
                             accuracy_test_zero_patch_after + accuracy_test_zero_no_patch_after) / 4

            # Append results to DataFrame
            new_row = pd.DataFrame([{
                "Seed": seed,
                "Percentage": percentage,
                "Val_Patch_Before": accuracy_val_patch_before,
                "Val_NoPatch_Before": accuracy_val_no_patch_before,
                "Val_Patch_After": accuracy_val_patch_after,
                "Val_NoPatch_After": accuracy_val_no_patch_after,
                "Test_Two_Patch_Before": accuracy_test_two_patch_before,
                "Test_Two_Patch_After": accuracy_test_two_patch_after,
                "Test_Two_NoPatch_Before": accuracy_test_two_no_patch_before,
                "Test_Two_NoPatch_After": accuracy_test_two_no_patch_after,
                "Test_Zero_Patch_Before": accuracy_test_zero_patch_before,
                "Test_Zero_Patch_After": accuracy_test_zero_patch_after,
                "Test_Zero_NoPatch_Before": accuracy_test_zero_no_patch_before,
                "Test_Zero_NoPatch_After": accuracy_test_zero_no_patch_after,
                "Worst_Acc_Before": worst_acc_before,
                "Worst_Acc_After": worst_acc_after,
                "Avg_Acc_Before": avg_acc_before,
                "Avg_Acc_After": avg_acc_after
            }])

            # Save results to CSV
            results_df = pd.concat([results_df, new_row], ignore_index=True)
    results_csv_path = os.path.join(folder_name, "background_200.csv")
    results_df.to_csv(results_csv_path, index=False)
    print(f"All results saved to {results_csv_path}")

if __name__ == "__main__":
    main()
# Out:
# Processing Seed 1
# Loading model from /content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_1.pt
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# <ipython-input-17-72707b08f62e>:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Model loaded successfully
# All layers frozen successfully
# <ipython-input-14-e4f67721c625>:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   autoencoder.load_state_dict(torch.load(save_sae_dir))  # Load weights
# Autoencoder loaded from /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background/l1_bg_autoencoder_layer_fc2_seed_1.pth and frozen successfully.
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Testing with 0% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 0% neurons (0 neurons) for muting.
# <ipython-input-20-a87bc54c2c98>:378: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# Testing with 1% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 1% neurons (160 neurons) for muting.
# Testing with 2% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 2% neurons (320 neurons) for muting.
# Testing with 3% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 3% neurons (480 neurons) for muting.
# Testing with 4% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 4% neurons (640 neurons) for muting.
# Testing with 5% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 5% neurons (800 neurons) for muting.
# Testing with 6% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 6% neurons (960 neurons) for muting.
# Testing with 7% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 7% neurons (1120 neurons) for muting.
# Testing with 8% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 8% neurons (1280 neurons) for muting.
# Testing with 9% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 9% neurons (1440 neurons) for muting.
# Testing with 10% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 10% neurons (1600 neurons) for muting.
# Testing with 11% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 11% neurons (1760 neurons) for muting.
# Testing with 12% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 12% neurons (1920 neurons) for muting.
# Testing with 13% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 13% neurons (2080 neurons) for muting.
# Testing with 14% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 14% neurons (2240 neurons) for muting.
# Testing with 15% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 15% neurons (2400 neurons) for muting.
# Testing with 16% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 16% neurons (2560 neurons) for muting.
# Testing with 17% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 17% neurons (2720 neurons) for muting.
# Testing with 18% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 18% neurons (2880 neurons) for muting.
# Testing with 19% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 19% neurons (3040 neurons) for muting.
# Testing with 20% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 20% neurons (3200 neurons) for muting.
# Testing with 21% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 21% neurons (3360 neurons) for muting.
# Testing with 22% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 22% neurons (3520 neurons) for muting.
# Testing with 23% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 23% neurons (3680 neurons) for muting.
# Testing with 24% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 24% neurons (3840 neurons) for muting.
# Testing with 25% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 25% neurons (4000 neurons) for muting.
# Testing with 26% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 26% neurons (4160 neurons) for muting.
# Testing with 27% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 27% neurons (4320 neurons) for muting.
# Testing with 28% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 28% neurons (4480 neurons) for muting.
# Testing with 29% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 29% neurons (4640 neurons) for muting.
# Testing with 30% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 30% neurons (4800 neurons) for muting.
# Testing with 31% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 31% neurons (4960 neurons) for muting.
# Testing with 32% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 32% neurons (5120 neurons) for muting.
# Testing with 33% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 33% neurons (5280 neurons) for muting.
# Testing with 34% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 34% neurons (5440 neurons) for muting.
# Testing with 35% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 35% neurons (5600 neurons) for muting.
# Testing with 36% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 36% neurons (5760 neurons) for muting.
# Testing with 37% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 37% neurons (5920 neurons) for muting.
# Testing with 38% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 38% neurons (6080 neurons) for muting.
# Testing with 39% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 39% neurons (6240 neurons) for muting.
# Testing with 40% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 40% neurons (6400 neurons) for muting.
# Testing with 41% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 41% neurons (6560 neurons) for muting.
# Testing with 42% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 42% neurons (6720 neurons) for muting.
# Testing with 43% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 43% neurons (6880 neurons) for muting.
# Testing with 44% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 44% neurons (7040 neurons) for muting.
# Testing with 45% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 45% neurons (7200 neurons) for muting.
# Testing with 46% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 46% neurons (7360 neurons) for muting.
# Testing with 47% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 47% neurons (7520 neurons) for muting.
# Testing with 48% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 48% neurons (7680 neurons) for muting.
# Testing with 49% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 49% neurons (7840 neurons) for muting.
# Testing with 50% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1_200.csv
# Loaded top 50% neurons (8000 neurons) for muting.
#
# Processing Seed 11
# Loading model from /content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_11.pt
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# <ipython-input-17-72707b08f62e>:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Model loaded successfully
# All layers frozen successfully
# <ipython-input-14-e4f67721c625>:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   autoencoder.load_state_dict(torch.load(save_sae_dir))  # Load weights
# Autoencoder loaded from /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background/l1_bg_autoencoder_layer_fc2_seed_11.pth and frozen successfully.
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Testing with 0% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 0% neurons (0 neurons) for muting.
# Testing with 1% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 1% neurons (160 neurons) for muting.
# Testing with 2% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 2% neurons (320 neurons) for muting.
# Testing with 3% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 3% neurons (480 neurons) for muting.
# Testing with 4% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 4% neurons (640 neurons) for muting.
# Testing with 5% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 5% neurons (800 neurons) for muting.
# Testing with 6% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 6% neurons (960 neurons) for muting.
# Testing with 7% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 7% neurons (1120 neurons) for muting.
# Testing with 8% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 8% neurons (1280 neurons) for muting.
# Testing with 9% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 9% neurons (1440 neurons) for muting.
# Testing with 10% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 10% neurons (1600 neurons) for muting.
# Testing with 11% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 11% neurons (1760 neurons) for muting.
# Testing with 12% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 12% neurons (1920 neurons) for muting.
# Testing with 13% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 13% neurons (2080 neurons) for muting.
# Testing with 14% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 14% neurons (2240 neurons) for muting.
# Testing with 15% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 15% neurons (2400 neurons) for muting.
# Testing with 16% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 16% neurons (2560 neurons) for muting.
# Testing with 17% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 17% neurons (2720 neurons) for muting.
# Testing with 18% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 18% neurons (2880 neurons) for muting.
# Testing with 19% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 19% neurons (3040 neurons) for muting.
# Testing with 20% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 20% neurons (3200 neurons) for muting.
# Testing with 21% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 21% neurons (3360 neurons) for muting.
# Testing with 22% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 22% neurons (3520 neurons) for muting.
# Testing with 23% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 23% neurons (3680 neurons) for muting.
# Testing with 24% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 24% neurons (3840 neurons) for muting.
# Testing with 25% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 25% neurons (4000 neurons) for muting.
# Testing with 26% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 26% neurons (4160 neurons) for muting.
# Testing with 27% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 27% neurons (4320 neurons) for muting.
# Testing with 28% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 28% neurons (4480 neurons) for muting.
# Testing with 29% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 29% neurons (4640 neurons) for muting.
# Testing with 30% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 30% neurons (4800 neurons) for muting.
# Testing with 31% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 31% neurons (4960 neurons) for muting.
# Testing with 32% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 32% neurons (5120 neurons) for muting.
# Testing with 33% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 33% neurons (5280 neurons) for muting.
# Testing with 34% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 34% neurons (5440 neurons) for muting.
# Testing with 35% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 35% neurons (5600 neurons) for muting.
# Testing with 36% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 36% neurons (5760 neurons) for muting.
# Testing with 37% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 37% neurons (5920 neurons) for muting.
# Testing with 38% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 38% neurons (6080 neurons) for muting.
# Testing with 39% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 39% neurons (6240 neurons) for muting.
# Testing with 40% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 40% neurons (6400 neurons) for muting.
# Testing with 41% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 41% neurons (6560 neurons) for muting.
# Testing with 42% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 42% neurons (6720 neurons) for muting.
# Testing with 43% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 43% neurons (6880 neurons) for muting.
# Testing with 44% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 44% neurons (7040 neurons) for muting.
# Testing with 45% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 45% neurons (7200 neurons) for muting.
# Testing with 46% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 46% neurons (7360 neurons) for muting.
# Testing with 47% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 47% neurons (7520 neurons) for muting.
# Testing with 48% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 48% neurons (7680 neurons) for muting.
# Testing with 49% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 49% neurons (7840 neurons) for muting.
# Testing with 50% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_11_200.csv
# Loaded top 50% neurons (8000 neurons) for muting.
#
# Processing Seed 111
# Loading model from /content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_111.pt
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# <ipython-input-17-72707b08f62e>:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Model loaded successfully
# All layers frozen successfully
# <ipython-input-14-e4f67721c625>:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   autoencoder.load_state_dict(torch.load(save_sae_dir))  # Load weights
# Autoencoder loaded from /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background/l1_bg_autoencoder_layer_fc2_seed_111.pth and frozen successfully.
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Projecting Alexnet activations into SAE sparse space...
# Testing with 0% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_111_200.csv
# Loaded top 0% neurons (0 neurons) for muting.
# Testing with 1% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_111_200.csv
# Loaded top 1% neurons (160 neurons) for muting.
# Testing with 2% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# ...
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 8% neurons (1280 neurons) for muting.
# Testing with 9% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 9% neurons (1440 neurons) for muting.
# Testing with 10% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 10% neurons (1600 neurons) for muting.
# Testing with 11% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 11% neurons (1760 neurons) for muting.
# Testing with 12% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 12% neurons (1920 neurons) for muting.
# Testing with 13% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 13% neurons (2080 neurons) for muting.
# Testing with 14% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 14% neurons (2240 neurons) for muting.
# Testing with 15% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 15% neurons (2400 neurons) for muting.
# Testing with 16% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 16% neurons (2560 neurons) for muting.
# Testing with 17% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 17% neurons (2720 neurons) for muting.
# Testing with 18% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 18% neurons (2880 neurons) for muting.
# Testing with 19% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 19% neurons (3040 neurons) for muting.
# Testing with 20% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 20% neurons (3200 neurons) for muting.
# Testing with 21% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 21% neurons (3360 neurons) for muting.
# Testing with 22% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 22% neurons (3520 neurons) for muting.
# Testing with 23% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 23% neurons (3680 neurons) for muting.
# Testing with 24% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 24% neurons (3840 neurons) for muting.
# Testing with 25% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 25% neurons (4000 neurons) for muting.
# Testing with 26% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 26% neurons (4160 neurons) for muting.
# Testing with 27% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 27% neurons (4320 neurons) for muting.
# Testing with 28% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 28% neurons (4480 neurons) for muting.
# Testing with 29% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 29% neurons (4640 neurons) for muting.
# Testing with 30% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 30% neurons (4800 neurons) for muting.
# Testing with 31% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 31% neurons (4960 neurons) for muting.
# Testing with 32% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 32% neurons (5120 neurons) for muting.
# Testing with 33% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 33% neurons (5280 neurons) for muting.
# Testing with 34% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 34% neurons (5440 neurons) for muting.
# Testing with 35% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 35% neurons (5600 neurons) for muting.
# Testing with 36% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 36% neurons (5760 neurons) for muting.
# Testing with 37% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 37% neurons (5920 neurons) for muting.
# Testing with 38% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 38% neurons (6080 neurons) for muting.
# Testing with 39% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 39% neurons (6240 neurons) for muting.
# Testing with 40% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 40% neurons (6400 neurons) for muting.
# Testing with 41% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 41% neurons (6560 neurons) for muting.
# Testing with 42% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 42% neurons (6720 neurons) for muting.
# Testing with 43% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 43% neurons (6880 neurons) for muting.
# Testing with 44% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 44% neurons (7040 neurons) for muting.
# Testing with 45% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 45% neurons (7200 neurons) for muting.
# Testing with 46% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 46% neurons (7360 neurons) for muting.
# Testing with 47% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 47% neurons (7520 neurons) for muting.
# Testing with 48% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 48% neurons (7680 neurons) for muting.
# Testing with 49% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 49% neurons (7840 neurons) for muting.
# Testing with 50% muting...
# Number of val patch neurons: 16000
# Number of val patch images: 200
# Number of pp labels: 400
# shape of correlations (16000,)
# Neuron correlations saved at: /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/l1_neurons_by_correlation_seed_1111111_200.csv
# Loaded top 50% neurons (8000 neurons) for muting.
# All results saved to /content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background/background_200.csv

# %% [markdown]
# ### 100

# %%
from sklearn.metrics import accuracy_score
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Function 12 to classify decoded activations
def classify_decoded_activations(model, decoded_activations):
    """Classify decoded activations using the softmax layer of the model."""
    predictions = []
    for activation in decoded_activations:
        # Convert numpy activation to a tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)

        # Pass through classifier[5] (ReLU)
        relu_output = model.classifier[5](activation_tensor)

        # Pass through classifier[6] (final linear layer)
        output = model.classifier[6](relu_output)

        # Apply softmax and get the predicted class
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)

    return predictions

# Function to calculate and plot correlation histograms
def plot_correlation_histogram(original, projected, title):
    correlations = [
        np.corrcoef(original[:, i], projected[:, i])[0, 1]
        if np.std(original[:, i]) > 0 and np.std(projected[:, i]) > 0
        else 0  # Handle constant features
        for i in range(original.shape[1])
    ]
    correlations = np.nan_to_num(correlations)  # Replace NaNs with 0
    plt.hist(correlations, bins=50, alpha=0.7)
    plt.title(title)
    plt.xlabel("Correlation")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

# Project activations into sparse space
def project_activations(autoencoder, activations, device):
    print("Projecting Alexnet activations into SAE sparse space...")
    with torch.no_grad():
        projected = autoencoder.encoder(torch.from_numpy(activations).to(device).float())
    return projected.cpu().numpy()

# Save all neuron differences and indexes in descending order
def save_all_neurons_to_csv(abs_diff, folder_name, filename="all_neuron_differences_100.csv"):
    """
    Save all neuron indexes sorted by their differences (descending order) to a CSV file.
    """
    print(f"Saving all neuron differences to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

    return csv_path # return the csv_path


def save_neurons_by_correlation(val_patch_activations, val_no_patch_activations, folder_name, filename="neurons_by_correlation_100.csv"):
    os.makedirs(folder_name, exist_ok=True)

    # Number of neurons should be 16k
    num_neurons = val_patch_activations.shape[1]
    print(f"Number of val patch neurons: {num_neurons}")
    num_images = val_patch_activations.shape[0]
    print(f"Number of val patch images: {val_patch_activations.shape[0]}")

    # Create a binary label vector pp (1 for patch, 0 for no patch)
    pp = np.concatenate([np.ones(val_patch_activations.shape[0]), np.zeros(val_no_patch_activations.shape[0])])
    print(f"Number of pp labels: {len(pp)}")

    # array to store correlations
    correlations = np.zeros(num_neurons)

    for i in range(num_neurons):
        # Combine activations for neuron i from both datassets p and np
        act_i = np.concatenate([val_patch_activations[:, i], val_no_patch_activations[:, i]])

        # Compute correlation between pp and act_i
        if np.std(pp) > 0 and np.std(act_i) > 0:
            corr = np.corrcoef(pp, act_i)[0, 1]
        else:
            corr = 0  # Handle constant vectors

        correlations[i] = corr

    # As previous code
    # Handle NaN correlations (replace NaN with 0)
    correlations = np.nan_to_num(correlations)
    print('shape of correlations', correlations.shape)

    # Create a DataFrame with neuron indices and their correlations
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(num_neurons),
        "Correlation": correlations
    })

    # Sort by correlation in descending order
    neuron_data.sort_values(by="Correlation", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"Neuron correlations saved at: {csv_path}")

    return csv_path

def save_top_neurons_to_csv(abs_diff, top_neurons, folder_name, filename="bg_top_neurons_100.csv"):
    """
    Save the top neurons with their difference values to a CSV file.
    """
    print(f"Saving top neurons to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": range(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Mark whether each neuron is in the top 10%
    neuron_data["Selected_for_Muting"] = neuron_data["Neuron_Index"].isin(top_neurons)

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

# Function to load top neurons from CSV based on a percentage
def load_top_neurons_from_csv(folder_name, filename, percentage):
    """
    Load top neurons based on the specified percentage from the saved CSV file.
    """
    csv_path = os.path.join(folder_name, filename)
    neuron_data = pd.read_csv(csv_path)

    # Calculate the number of top neurons to select
    top_count = int(len(neuron_data) * (percentage / 100))

    # Select the top neurons based on their activation difference
    top_neurons = neuron_data.iloc[:top_count]["Neuron_Index"].values
    print(f"Loaded top {percentage}% neurons ({top_count} neurons) for muting.")
    return top_neurons


def classify_with_alexnet(model, activations):
    """
    Classify images using the original AlexNet classifier on the fc2 activations.
    """
    predictions = []
    for activation in activations:
        # Convert numpy activation to tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)
        relu_output = model.classifier[5](activation_tensor)  # Apply ReLU
        output = model.classifier[6](relu_output)  # Apply fc3
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)
    return predictions

# Function to calculate accuracy per group
def calculate_group_accuracy(predictions, true_labels):
    return accuracy_score(true_labels, predictions)


def main():
    import pandas as pd
    import os
    import numpy as np
    import torch

    seeds = [1, 11, 111, 1111, 11111, 111111, 1111111] #!!!!!

    # Paths to models, activations, and autoencoders for each seed
    model_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_{seed}.pt"
        for seed in seeds
    ]
    autoencoder_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background/l1_bg_autoencoder_layer_fc2_seed_{seed}.pth"
        for seed in seeds
    ]
    test_activation_two_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_two_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]

    # Output folder for results
    folder_name = "/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background"
    os.makedirs(folder_name, exist_ok=True)

    # Prepare a DataFrame to store results
    results_df = pd.DataFrame(columns=[
        "Seed", "Percentage",
        "Val_Patch_Before", "Val_NoPatch_Before",
        "Val_Patch_After", "Val_NoPatch_After",
        "Test_Two_Patch_Before", "Test_Two_NoPatch_Before",
        "Test_Two_Patch_After", "Test_Two_NoPatch_After",
        "Test_Zero_Patch_Before", "Test_Zero_NoPatch_Before",
        "Test_Zero_Patch_After", "Test_Zero_NoPatch_After",
        "Worst_Acc_Before", "Worst_Acc_After",
        "Avg_Acc_Before", "Avg_Acc_After"
    ])

    # Loop through seeds/models/autoencoders
    for seed_idx, seed in enumerate(seeds):
        print(f"\nProcessing Seed {seed}")

        # Load paths
        model_path = model_paths[seed_idx]
        sae_path = autoencoder_paths[seed_idx]
        val_patch_path = val_activation_patch_paths[seed_idx]
        val_no_patch_path = val_activation_no_patch_paths[seed_idx]
        test_two_patch_path = test_activation_two_patch_paths[seed_idx]
        test_two_no_patch_path = test_activation_two_no_patch_paths[seed_idx]
        test_zero_patch_path = test_activation_zero_patch_paths[seed_idx]
        test_zero_no_patch_path = test_activation_zero_no_patch_paths[seed_idx]

        # Load the model and autoencoder
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = load_model(model_path, device)
        autoencoder = load_autoencoder(device, sae_path)

        # Load pre-saved activations
        val_activations_patch = np.load(val_patch_path, allow_pickle=True)
        val_activations_no_patch = np.load(val_no_patch_path, allow_pickle=True)

        test_two_patch = np.load(test_two_patch_path, allow_pickle=True)
        test_two_no_patch = np.load(test_two_no_patch_path, allow_pickle=True)
        test_zero_patch = np.load(test_zero_patch_path, allow_pickle=True)
        test_zero_no_patch = np.load(test_zero_no_patch_path, allow_pickle=True)

        # Classify "before muting"
        predictions_val_patch_before = classify_with_alexnet(model, val_activations_patch)
        predictions_val_no_patch_before = classify_with_alexnet(model, val_activations_no_patch)
        accuracy_val_patch_before = calculate_group_accuracy(predictions_val_patch_before, [0] * len(predictions_val_patch_before))
        accuracy_val_no_patch_before = calculate_group_accuracy(predictions_val_no_patch_before, [0] * len(predictions_val_no_patch_before))

        predictions_test_two_patch_before = classify_with_alexnet(model, test_two_patch)
        predictions_test_two_no_patch_before = classify_with_alexnet(model, test_two_no_patch)
        predictions_test_zero_patch_before = classify_with_alexnet(model, test_zero_patch)
        predictions_test_zero_no_patch_before = classify_with_alexnet(model, test_zero_no_patch)

        accuracy_test_two_patch_before = calculate_group_accuracy(predictions_test_two_patch_before, [1] * len(predictions_test_two_patch_before))
        accuracy_test_two_no_patch_before = calculate_group_accuracy(predictions_test_two_no_patch_before, [1] * len(predictions_test_two_no_patch_before))
        accuracy_test_zero_patch_before = calculate_group_accuracy(predictions_test_zero_patch_before, [0] * len(predictions_test_zero_patch_before))
        accuracy_test_zero_no_patch_before = calculate_group_accuracy(predictions_test_zero_no_patch_before, [0] * len(predictions_test_zero_no_patch_before))

        # Project activations
        projected_val_patch = project_activations(autoencoder, val_activations_patch, device)
        projected_val_no_patch = project_activations(autoencoder, val_activations_no_patch, device)
        projected_two_test_patch = project_activations(autoencoder, test_two_patch, device)
        projected_two_test_no_patch = project_activations(autoencoder, test_two_no_patch, device)
        projected_zero_test_patch = project_activations(autoencoder, test_zero_patch, device)
        projected_zero_test_no_patch = project_activations(autoencoder, test_zero_no_patch, device)



        # Loop through percentages
        for percentage in range(0, 51):  # 1% to 15%
            print(f"Testing with {percentage}% muting...")

            correlation_csv_path = save_neurons_by_correlation(
                projected_val_patch, projected_val_no_patch, folder_name, filename=f"l1_neurons_by_correlation_seed_{seed}_100.csv"
            )
            top_neurons_corr = load_top_neurons_from_csv(folder_name, f"l1_neurons_by_correlation_seed_{seed}_100.csv", percentage)

            top_neurons = top_neurons_corr

            # Muting neurons
            projected_val_patch_muted = projected_val_patch.copy()
            projected_val_no_patch_muted = projected_val_no_patch.copy()
            projected_two_test_patch_muted = projected_two_test_patch.copy()
            projected_two_test_no_patch_muted = projected_two_test_no_patch.copy()
            projected_zero_test_patch_muted = projected_zero_test_patch.copy()
            projected_zero_test_no_patch_muted = projected_zero_test_no_patch.copy()

            projected_val_patch_muted[:, top_neurons] = 0
            projected_val_no_patch_muted[:, top_neurons] = 0
            projected_two_test_patch_muted[:, top_neurons] = 0
            projected_two_test_no_patch_muted[:, top_neurons] = 0
            projected_zero_test_patch_muted[:, top_neurons] = 0
            projected_zero_test_no_patch_muted[:, top_neurons] = 0

            # Decode and classify
            decoded_val_patch = autoencoder.decoder(torch.from_numpy(projected_val_patch_muted).to(device).float()).cpu().numpy()
            decoded_val_no_patch = autoencoder.decoder(torch.from_numpy(projected_val_no_patch_muted).to(device).float()).cpu().numpy()
            decoded_two_test_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_patch_muted).to(device).float()).cpu().numpy()
            decoded_two_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_no_patch_muted).to(device).float()).cpu().numpy()
            decoded_zero_test_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_patch_muted).to(device).float()).cpu().numpy()
            decoded_zero_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_no_patch_muted).to(device).float()).cpu().numpy()

            predictions_val_patch_after = classify_decoded_activations(model, decoded_val_patch)
            predictions_val_no_patch_after = classify_decoded_activations(model, decoded_val_no_patch)
            predictions_test_two_patch_after = classify_decoded_activations(model, decoded_two_test_patch)
            predictions_test_two_no_patch_after = classify_decoded_activations(model, decoded_two_test_no_patch)
            predictions_test_zero_patch_after = classify_decoded_activations(model, decoded_zero_test_patch)
            predictions_test_zero_no_patch_after = classify_decoded_activations(model, decoded_zero_test_no_patch)

            accuracy_val_patch_after = calculate_group_accuracy(predictions_val_patch_after, [0] * len(predictions_val_patch_after))
            accuracy_val_no_patch_after = calculate_group_accuracy(predictions_val_no_patch_after, [0] * len(predictions_val_no_patch_after))
            accuracy_test_two_patch_after = calculate_group_accuracy(predictions_test_two_patch_after, [1] * len(predictions_test_two_patch_after))
            accuracy_test_two_no_patch_after = calculate_group_accuracy(predictions_test_two_no_patch_after, [1] * len(predictions_test_two_no_patch_after))
            accuracy_test_zero_patch_after = calculate_group_accuracy(predictions_test_zero_patch_after, [0] * len(predictions_test_zero_patch_after))
            accuracy_test_zero_no_patch_after = calculate_group_accuracy(predictions_test_zero_no_patch_after, [0] * len(predictions_test_zero_no_patch_after))

            # Calculate worst and average group accuracies
            worst_acc_before = min(accuracy_test_two_patch_before, accuracy_test_two_no_patch_before)
            worst_acc_after = min(accuracy_test_two_patch_after, accuracy_test_two_no_patch_after)
            avg_acc_before = (accuracy_test_two_patch_before + accuracy_test_two_no_patch_before +
                              accuracy_test_zero_patch_before + accuracy_test_zero_no_patch_before) / 4
            avg_acc_after = (accuracy_test_two_patch_after + accuracy_test_two_no_patch_after +
                             accuracy_test_zero_patch_after + accuracy_test_zero_no_patch_after) / 4

            # Append results to DataFrame
            new_row = pd.DataFrame([{
                "Seed": seed,
                "Percentage": percentage,
                "Val_Patch_Before": accuracy_val_patch_before,
                "Val_NoPatch_Before": accuracy_val_no_patch_before,
                "Val_Patch_After": accuracy_val_patch_after,
                "Val_NoPatch_After": accuracy_val_no_patch_after,
                "Test_Two_Patch_Before": accuracy_test_two_patch_before,
                "Test_Two_Patch_After": accuracy_test_two_patch_after,
                "Test_Two_NoPatch_Before": accuracy_test_two_no_patch_before,
                "Test_Two_NoPatch_After": accuracy_test_two_no_patch_after,
                "Test_Zero_Patch_Before": accuracy_test_zero_patch_before,
                "Test_Zero_Patch_After": accuracy_test_zero_patch_after,
                "Test_Zero_NoPatch_Before": accuracy_test_zero_no_patch_before,
                "Test_Zero_NoPatch_After": accuracy_test_zero_no_patch_after,
                "Worst_Acc_Before": worst_acc_before,
                "Worst_Acc_After": worst_acc_after,
                "Avg_Acc_Before": avg_acc_before,
                "Avg_Acc_After": avg_acc_after
            }])

            # Save results to CSV
            results_df = pd.concat([results_df, new_row], ignore_index=True)
    results_csv_path = os.path.join(folder_name, "background_100.csv")
    results_df.to_csv(results_csv_path, index=False)
    print(f"All results saved to {results_csv_path}")

if __name__ == "__main__":
    main()

# %%
stophere
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-88d56cf18612> in <cell line: 0>()
# ----> 1 stophere
#
# NameError: name 'stophere' is not defined

# %% [markdown]
# ### 50

# %%
from sklearn.metrics import accuracy_score
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Function 12 to classify decoded activations
def classify_decoded_activations(model, decoded_activations):
    """Classify decoded activations using the softmax layer of the model."""
    predictions = []
    for activation in decoded_activations:
        # Convert numpy activation to a tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)

        # Pass through classifier[5] (ReLU)
        relu_output = model.classifier[5](activation_tensor)

        # Pass through classifier[6] (final linear layer)
        output = model.classifier[6](relu_output)

        # Apply softmax and get the predicted class
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)

    return predictions

# Function to calculate and plot correlation histograms
def plot_correlation_histogram(original, projected, title):
    correlations = [
        np.corrcoef(original[:, i], projected[:, i])[0, 1]
        if np.std(original[:, i]) > 0 and np.std(projected[:, i]) > 0
        else 0  # Handle constant features
        for i in range(original.shape[1])
    ]
    correlations = np.nan_to_num(correlations)  # Replace NaNs with 0
    plt.hist(correlations, bins=50, alpha=0.7)
    plt.title(title)
    plt.xlabel("Correlation")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

# Project activations into sparse space
def project_activations(autoencoder, activations, device):
    print("Projecting Alexnet activations into SAE sparse space...")
    with torch.no_grad():
        projected = autoencoder.encoder(torch.from_numpy(activations).to(device).float())
    return projected.cpu().numpy()

# Save all neuron differences and indexes in descending order
def save_all_neurons_to_csv(abs_diff, folder_name, filename="all_neuron_differences_50.csv"):
    """
    Save all neuron indexes sorted by their differences (descending order) to a CSV file.
    """
    print(f"Saving all neuron differences to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

    return csv_path # return the csv_path


def save_neurons_by_correlation(val_patch_activations, val_no_patch_activations, folder_name, filename="neurons_by_correlation_50.csv"):
    os.makedirs(folder_name, exist_ok=True)

    # Number of neurons should be 16k
    num_neurons = val_patch_activations.shape[1]
    print(f"Number of val patch neurons: {num_neurons}")
    num_images = val_patch_activations.shape[0]
    print(f"Number of val patch images: {val_patch_activations.shape[0]}")

    # Create a binary label vector pp (1 for patch, 0 for no patch)
    pp = np.concatenate([np.ones(val_patch_activations.shape[0]), np.zeros(val_no_patch_activations.shape[0])])
    print(f"Number of pp labels: {len(pp)}")

    # array to store correlations
    correlations = np.zeros(num_neurons)

    for i in range(num_neurons):
        # Combine activations for neuron i from both datassets p and np
        act_i = np.concatenate([val_patch_activations[:, i], val_no_patch_activations[:, i]])

        # Compute correlation between pp and act_i
        if np.std(pp) > 0 and np.std(act_i) > 0:
            corr = np.corrcoef(pp, act_i)[0, 1]
        else:
            corr = 0  # Handle constant vectors

        correlations[i] = corr

    # As previous code
    # Handle NaN correlations (replace NaN with 0)
    correlations = np.nan_to_num(correlations)
    print('shape of correlations', correlations.shape)

    # Create a DataFrame with neuron indices and their correlations
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(num_neurons),
        "Correlation": correlations
    })

    # Sort by correlation in descending order
    neuron_data.sort_values(by="Correlation", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"Neuron correlations saved at: {csv_path}")

    return csv_path

def save_top_neurons_to_csv(abs_diff, top_neurons, folder_name, filename="bg_top_neurons_50.csv"):
    """
    Save the top neurons with their difference values to a CSV file.
    """
    print(f"Saving top neurons to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": range(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Mark whether each neuron is in the top 10%
    neuron_data["Selected_for_Muting"] = neuron_data["Neuron_Index"].isin(top_neurons)

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

# Function to load top neurons from CSV based on a percentage
def load_top_neurons_from_csv(folder_name, filename, percentage):
    """
    Load top neurons based on the specified percentage from the saved CSV file.
    """
    csv_path = os.path.join(folder_name, filename)
    neuron_data = pd.read_csv(csv_path)

    # Calculate the number of top neurons to select
    top_count = int(len(neuron_data) * (percentage / 100))

    # Select the top neurons based on their activation difference
    top_neurons = neuron_data.iloc[:top_count]["Neuron_Index"].values
    print(f"Loaded top {percentage}% neurons ({top_count} neurons) for muting.")
    return top_neurons


def classify_with_alexnet(model, activations):
    """
    Classify images using the original AlexNet classifier on the fc2 activations.
    """
    predictions = []
    for activation in activations:
        # Convert numpy activation to tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)
        relu_output = model.classifier[5](activation_tensor)  # Apply ReLU
        output = model.classifier[6](relu_output)  # Apply fc3
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)
    return predictions

# Function to calculate accuracy per group
def calculate_group_accuracy(predictions, true_labels):
    return accuracy_score(true_labels, predictions)


def main():
    import pandas as pd
    import os
    import numpy as np
    import torch

    seeds = [1, 11, 111, 1111, 111111, 111111, 1111111] #!!!!!

    # Paths to models, activations, and autoencoders for each seed
    model_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_{seed}.pt"
        for seed in seeds
    ]
    autoencoder_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background/l1_bg_autoencoder_layer_fc2_seed_{seed}.pth"
        for seed in seeds
    ]
    test_activation_two_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_two_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_bg_50_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_org_50_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]

    # Output folder for results
    folder_name = "/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background"
    os.makedirs(folder_name, exist_ok=True)

    # Prepare a DataFrame to store results
    results_df = pd.DataFrame(columns=[
        "Seed", "Percentage",
        "Val_Patch_Before", "Val_NoPatch_Before",
        "Val_Patch_After", "Val_NoPatch_After",
        "Test_Two_Patch_Before", "Test_Two_NoPatch_Before",
        "Test_Two_Patch_After", "Test_Two_NoPatch_After",
        "Test_Zero_Patch_Before", "Test_Zero_NoPatch_Before",
        "Test_Zero_Patch_After", "Test_Zero_NoPatch_After",
        "Worst_Acc_Before", "Worst_Acc_After",
        "Avg_Acc_Before", "Avg_Acc_After"
    ])

    # Loop through seeds/models/autoencoders
    for seed_idx, seed in enumerate(seeds):
        print(f"\nProcessing Seed {seed}")

        # Load paths
        model_path = model_paths[seed_idx]
        sae_path = autoencoder_paths[seed_idx]
        val_patch_path = val_activation_patch_paths[seed_idx]
        val_no_patch_path = val_activation_no_patch_paths[seed_idx]
        test_two_patch_path = test_activation_two_patch_paths[seed_idx]
        test_two_no_patch_path = test_activation_two_no_patch_paths[seed_idx]
        test_zero_patch_path = test_activation_zero_patch_paths[seed_idx]
        test_zero_no_patch_path = test_activation_zero_no_patch_paths[seed_idx]

        # Load the model and autoencoder
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = load_model(model_path, device)
        autoencoder = load_autoencoder(device, sae_path)

        # Load pre-saved activations
        val_activations_patch = np.load(val_patch_path, allow_pickle=True)
        val_activations_no_patch = np.load(val_no_patch_path, allow_pickle=True)

        test_two_patch = np.load(test_two_patch_path, allow_pickle=True)
        test_two_no_patch = np.load(test_two_no_patch_path, allow_pickle=True)
        test_zero_patch = np.load(test_zero_patch_path, allow_pickle=True)
        test_zero_no_patch = np.load(test_zero_no_patch_path, allow_pickle=True)

        # Classify "before muting"
        predictions_val_patch_before = classify_with_alexnet(model, val_activations_patch)
        predictions_val_no_patch_before = classify_with_alexnet(model, val_activations_no_patch)
        accuracy_val_patch_before = calculate_group_accuracy(predictions_val_patch_before, [0] * len(predictions_val_patch_before))
        accuracy_val_no_patch_before = calculate_group_accuracy(predictions_val_no_patch_before, [0] * len(predictions_val_no_patch_before))

        predictions_test_two_patch_before = classify_with_alexnet(model, test_two_patch)
        predictions_test_two_no_patch_before = classify_with_alexnet(model, test_two_no_patch)
        predictions_test_zero_patch_before = classify_with_alexnet(model, test_zero_patch)
        predictions_test_zero_no_patch_before = classify_with_alexnet(model, test_zero_no_patch)

        accuracy_test_two_patch_before = calculate_group_accuracy(predictions_test_two_patch_before, [1] * len(predictions_test_two_patch_before))
        accuracy_test_two_no_patch_before = calculate_group_accuracy(predictions_test_two_no_patch_before, [1] * len(predictions_test_two_no_patch_before))
        accuracy_test_zero_patch_before = calculate_group_accuracy(predictions_test_zero_patch_before, [0] * len(predictions_test_zero_patch_before))
        accuracy_test_zero_no_patch_before = calculate_group_accuracy(predictions_test_zero_no_patch_before, [0] * len(predictions_test_zero_no_patch_before))

        # Project activations
        projected_val_patch = project_activations(autoencoder, val_activations_patch, device)
        projected_val_no_patch = project_activations(autoencoder, val_activations_no_patch, device)
        projected_two_test_patch = project_activations(autoencoder, test_two_patch, device)
        projected_two_test_no_patch = project_activations(autoencoder, test_two_no_patch, device)
        projected_zero_test_patch = project_activations(autoencoder, test_zero_patch, device)
        projected_zero_test_no_patch = project_activations(autoencoder, test_zero_no_patch, device)



        # Loop through percentages
        for percentage in range(0, 51):  # 1% to 15%
            print(f"Testing with {percentage}% muting...")

            # Calculate differences and load top neurons
            #abs_diff = np.abs(np.mean(projected_val_patch, axis=0) - np.mean(projected_val_no_patch, axis=0))
            #csv_path = save_all_neurons_to_csv(abs_diff, folder_name, filename=f"mnist_bg_val_neuron_differences_seed_{seed}.csv")
            #top_neurons = load_top_neurons_from_csv(folder_name, f"mnist_bg_val_neuron_differences_seed_{seed}.csv", percentage)


            # **Correlation-Based Neurons**
            correlation_csv_path = save_neurons_by_correlation(
                projected_val_patch, projected_val_no_patch, folder_name, filename=f"l1_neurons_by_correlation_seed_{seed}_50.csv"
            )
            top_neurons_corr = load_top_neurons_from_csv(folder_name, f"l1_neurons_by_correlation_seed_{seed}_50.csv", percentage)

            top_neurons = top_neurons_corr

            # Muting neurons
            projected_val_patch_muted = projected_val_patch.copy()
            projected_val_no_patch_muted = projected_val_no_patch.copy()
            projected_two_test_patch_muted = projected_two_test_patch.copy()
            projected_two_test_no_patch_muted = projected_two_test_no_patch.copy()
            projected_zero_test_patch_muted = projected_zero_test_patch.copy()
            projected_zero_test_no_patch_muted = projected_zero_test_no_patch.copy()

            projected_val_patch_muted[:, top_neurons] = 0
            projected_val_no_patch_muted[:, top_neurons] = 0
            projected_two_test_patch_muted[:, top_neurons] = 0
            projected_two_test_no_patch_muted[:, top_neurons] = 0
            projected_zero_test_patch_muted[:, top_neurons] = 0
            projected_zero_test_no_patch_muted[:, top_neurons] = 0

            # Decode and classify
            decoded_val_patch = autoencoder.decoder(torch.from_numpy(projected_val_patch_muted).to(device).float()).cpu().numpy()
            decoded_val_no_patch = autoencoder.decoder(torch.from_numpy(projected_val_no_patch_muted).to(device).float()).cpu().numpy()
            decoded_two_test_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_patch_muted).to(device).float()).cpu().numpy()
            decoded_two_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_no_patch_muted).to(device).float()).cpu().numpy()
            decoded_zero_test_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_patch_muted).to(device).float()).cpu().numpy()
            decoded_zero_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_no_patch_muted).to(device).float()).cpu().numpy()

            predictions_val_patch_after = classify_decoded_activations(model, decoded_val_patch)
            predictions_val_no_patch_after = classify_decoded_activations(model, decoded_val_no_patch)
            predictions_test_two_patch_after = classify_decoded_activations(model, decoded_two_test_patch)
            predictions_test_two_no_patch_after = classify_decoded_activations(model, decoded_two_test_no_patch)
            predictions_test_zero_patch_after = classify_decoded_activations(model, decoded_zero_test_patch)
            predictions_test_zero_no_patch_after = classify_decoded_activations(model, decoded_zero_test_no_patch)

            accuracy_val_patch_after = calculate_group_accuracy(predictions_val_patch_after, [0] * len(predictions_val_patch_after))
            accuracy_val_no_patch_after = calculate_group_accuracy(predictions_val_no_patch_after, [0] * len(predictions_val_no_patch_after))
            accuracy_test_two_patch_after = calculate_group_accuracy(predictions_test_two_patch_after, [1] * len(predictions_test_two_patch_after))
            accuracy_test_two_no_patch_after = calculate_group_accuracy(predictions_test_two_no_patch_after, [1] * len(predictions_test_two_no_patch_after))
            accuracy_test_zero_patch_after = calculate_group_accuracy(predictions_test_zero_patch_after, [0] * len(predictions_test_zero_patch_after))
            accuracy_test_zero_no_patch_after = calculate_group_accuracy(predictions_test_zero_no_patch_after, [0] * len(predictions_test_zero_no_patch_after))

            # Calculate worst and average group accuracies
            worst_acc_before = min(accuracy_test_two_patch_before, accuracy_test_two_no_patch_before)
            worst_acc_after = min(accuracy_test_two_patch_after, accuracy_test_two_no_patch_after)
            avg_acc_before = (accuracy_test_two_patch_before + accuracy_test_two_no_patch_before +
                              accuracy_test_zero_patch_before + accuracy_test_zero_no_patch_before) / 4
            avg_acc_after = (accuracy_test_two_patch_after + accuracy_test_two_no_patch_after +
                             accuracy_test_zero_patch_after + accuracy_test_zero_no_patch_after) / 4

            # Append results to DataFrame
            new_row = pd.DataFrame([{
                "Seed": seed,
                "Percentage": percentage,
                "Val_Patch_Before": accuracy_val_patch_before,
                "Val_NoPatch_Before": accuracy_val_no_patch_before,
                "Val_Patch_After": accuracy_val_patch_after,
                "Val_NoPatch_After": accuracy_val_no_patch_after,
                "Test_Two_Patch_Before": accuracy_test_two_patch_before,
                "Test_Two_Patch_After": accuracy_test_two_patch_after,
                "Test_Two_NoPatch_Before": accuracy_test_two_no_patch_before,
                "Test_Two_NoPatch_After": accuracy_test_two_no_patch_after,
                "Test_Zero_Patch_Before": accuracy_test_zero_patch_before,
                "Test_Zero_Patch_After": accuracy_test_zero_patch_after,
                "Test_Zero_NoPatch_Before": accuracy_test_zero_no_patch_before,
                "Test_Zero_NoPatch_After": accuracy_test_zero_no_patch_after,
                "Worst_Acc_Before": worst_acc_before,
                "Worst_Acc_After": worst_acc_after,
                "Avg_Acc_Before": avg_acc_before,
                "Avg_Acc_After": avg_acc_after
            }])

            # Save results to CSV
            results_df = pd.concat([results_df, new_row], ignore_index=True)
    results_csv_path = os.path.join(folder_name, "background_50.csv")
    results_df.to_csv(results_csv_path, index=False)
    print(f"All results saved to {results_csv_path}")

if __name__ == "__main__":
    main()

# %% [markdown]
# ### 25

# %%
from sklearn.metrics import accuracy_score
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Function 12 to classify decoded activations
def classify_decoded_activations(model, decoded_activations):
    """Classify decoded activations using the softmax layer of the model."""
    predictions = []
    for activation in decoded_activations:
        # Convert numpy activation to a tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)

        # Pass through classifier[5] (ReLU)
        relu_output = model.classifier[5](activation_tensor)

        # Pass through classifier[6] (final linear layer)
        output = model.classifier[6](relu_output)

        # Apply softmax and get the predicted class
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)

    return predictions

# Function to calculate and plot correlation histograms
def plot_correlation_histogram(original, projected, title):
    correlations = [
        np.corrcoef(original[:, i], projected[:, i])[0, 1]
        if np.std(original[:, i]) > 0 and np.std(projected[:, i]) > 0
        else 0  # Handle constant features
        for i in range(original.shape[1])
    ]
    correlations = np.nan_to_num(correlations)  # Replace NaNs with 0
    plt.hist(correlations, bins=50, alpha=0.7)
    plt.title(title)
    plt.xlabel("Correlation")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

# Project activations into sparse space
def project_activations(autoencoder, activations, device):
    print("Projecting Alexnet activations into SAE sparse space...")
    with torch.no_grad():
        projected = autoencoder.encoder(torch.from_numpy(activations).to(device).float())
    return projected.cpu().numpy()

# Save all neuron differences and indexes in descending order
def save_all_neurons_to_csv(abs_diff, folder_name, filename="all_neuron_differences_25.csv"):
    """
    Save all neuron indexes sorted by their differences (descending order) to a CSV file.
    """
    print(f"Saving all neuron differences to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

    return csv_path # return the csv_path


def save_neurons_by_correlation(val_patch_activations, val_no_patch_activations, folder_name, filename="neurons_by_correlation_25.csv"):
    os.makedirs(folder_name, exist_ok=True)

    # Number of neurons should be 16k
    num_neurons = val_patch_activations.shape[1]
    print(f"Number of val patch neurons: {num_neurons}")
    num_images = val_patch_activations.shape[0]
    print(f"Number of val patch images: {val_patch_activations.shape[0]}")

    # Create a binary label vector pp (1 for patch, 0 for no patch)
    pp = np.concatenate([np.ones(val_patch_activations.shape[0]), np.zeros(val_no_patch_activations.shape[0])])
    print(f"Number of pp labels: {len(pp)}")

    # array to store correlations
    correlations = np.zeros(num_neurons)

    for i in range(num_neurons):
        # Combine activations for neuron i from both datassets p and np
        act_i = np.concatenate([val_patch_activations[:, i], val_no_patch_activations[:, i]])

        # Compute correlation between pp and act_i
        if np.std(pp) > 0 and np.std(act_i) > 0:
            corr = np.corrcoef(pp, act_i)[0, 1]
        else:
            corr = 0  # Handle constant vectors

        correlations[i] = corr

    # As previous code
    # Handle NaN correlations (replace NaN with 0)
    correlations = np.nan_to_num(correlations)
    print('shape of correlations', correlations.shape)

    # Create a DataFrame with neuron indices and their correlations
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(num_neurons),
        "Correlation": correlations
    })

    # Sort by correlation in descending order
    neuron_data.sort_values(by="Correlation", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"Neuron correlations saved at: {csv_path}")

    return csv_path

def save_top_neurons_to_csv(abs_diff, top_neurons, folder_name, filename="bg_top_neurons_25.csv"):
    """
    Save the top neurons with their difference values to a CSV file.
    """
    print(f"Saving top neurons to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": range(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Mark whether each neuron is in the top 10%
    neuron_data["Selected_for_Muting"] = neuron_data["Neuron_Index"].isin(top_neurons)

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

# Function to load top neurons from CSV based on a percentage
def load_top_neurons_from_csv(folder_name, filename, percentage):
    """
    Load top neurons based on the specified percentage from the saved CSV file.
    """
    csv_path = os.path.join(folder_name, filename)
    neuron_data = pd.read_csv(csv_path)

    # Calculate the number of top neurons to select
    top_count = int(len(neuron_data) * (percentage / 100))

    # Select the top neurons based on their activation difference
    top_neurons = neuron_data.iloc[:top_count]["Neuron_Index"].values
    print(f"Loaded top {percentage}% neurons ({top_count} neurons) for muting.")
    return top_neurons


def classify_with_alexnet(model, activations):
    """
    Classify images using the original AlexNet classifier on the fc2 activations.
    """
    predictions = []
    for activation in activations:
        # Convert numpy activation to tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)
        relu_output = model.classifier[5](activation_tensor)  # Apply ReLU
        output = model.classifier[6](relu_output)  # Apply fc3
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)
    return predictions

# Function to calculate accuracy per group
def calculate_group_accuracy(predictions, true_labels):
    return accuracy_score(true_labels, predictions)


def main():
    import pandas as pd
    import os
    import numpy as np
    import torch

    seeds = [1, 11, 111, 1111, 111111, 111111, 1111111] #!!!!!

    # Paths to models, activations, and autoencoders for each seed
    model_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_{seed}.pt"
        for seed in seeds
    ]
    autoencoder_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/background/l1_bg_autoencoder_layer_fc2_seed_{seed}.pth"
        for seed in seeds
    ]
    test_activation_two_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_two_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_two_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_bg_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_test_zero_org_100_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_bg_25_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/background/fc2_activations_val_zero_org_25_alexnet_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]

    # Output folder for results
    folder_name = "/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/background"
    os.makedirs(folder_name, exist_ok=True)

    # Prepare a DataFrame to store results
    results_df = pd.DataFrame(columns=[
        "Seed", "Percentage",
        "Val_Patch_Before", "Val_NoPatch_Before",
        "Val_Patch_After", "Val_NoPatch_After",
        "Test_Two_Patch_Before", "Test_Two_NoPatch_Before",
        "Test_Two_Patch_After", "Test_Two_NoPatch_After",
        "Test_Zero_Patch_Before", "Test_Zero_NoPatch_Before",
        "Test_Zero_Patch_After", "Test_Zero_NoPatch_After",
        "Worst_Acc_Before", "Worst_Acc_After",
        "Avg_Acc_Before", "Avg_Acc_After"
    ])

    # Loop through seeds/models/autoencoders
    for seed_idx, seed in enumerate(seeds):
        print(f"\nProcessing Seed {seed}")

        # Load paths
        model_path = model_paths[seed_idx]
        sae_path = autoencoder_paths[seed_idx]
        val_patch_path = val_activation_patch_paths[seed_idx]
        val_no_patch_path = val_activation_no_patch_paths[seed_idx]
        test_two_patch_path = test_activation_two_patch_paths[seed_idx]
        test_two_no_patch_path = test_activation_two_no_patch_paths[seed_idx]
        test_zero_patch_path = test_activation_zero_patch_paths[seed_idx]
        test_zero_no_patch_path = test_activation_zero_no_patch_paths[seed_idx]

        # Load the model and autoencoder
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = load_model(model_path, device)
        autoencoder = load_autoencoder(device, sae_path)

        # Load pre-saved activations
        val_activations_patch = np.load(val_patch_path, allow_pickle=True)
        val_activations_no_patch = np.load(val_no_patch_path, allow_pickle=True)

        test_two_patch = np.load(test_two_patch_path, allow_pickle=True)
        test_two_no_patch = np.load(test_two_no_patch_path, allow_pickle=True)
        test_zero_patch = np.load(test_zero_patch_path, allow_pickle=True)
        test_zero_no_patch = np.load(test_zero_no_patch_path, allow_pickle=True)

        # Classify "before muting"
        predictions_val_patch_before = classify_with_alexnet(model, val_activations_patch)
        predictions_val_no_patch_before = classify_with_alexnet(model, val_activations_no_patch)
        accuracy_val_patch_before = calculate_group_accuracy(predictions_val_patch_before, [0] * len(predictions_val_patch_before))
        accuracy_val_no_patch_before = calculate_group_accuracy(predictions_val_no_patch_before, [0] * len(predictions_val_no_patch_before))

        predictions_test_two_patch_before = classify_with_alexnet(model, test_two_patch)
        predictions_test_two_no_patch_before = classify_with_alexnet(model, test_two_no_patch)
        predictions_test_zero_patch_before = classify_with_alexnet(model, test_zero_patch)
        predictions_test_zero_no_patch_before = classify_with_alexnet(model, test_zero_no_patch)

        accuracy_test_two_patch_before = calculate_group_accuracy(predictions_test_two_patch_before, [1] * len(predictions_test_two_patch_before))
        accuracy_test_two_no_patch_before = calculate_group_accuracy(predictions_test_two_no_patch_before, [1] * len(predictions_test_two_no_patch_before))
        accuracy_test_zero_patch_before = calculate_group_accuracy(predictions_test_zero_patch_before, [0] * len(predictions_test_zero_patch_before))
        accuracy_test_zero_no_patch_before = calculate_group_accuracy(predictions_test_zero_no_patch_before, [0] * len(predictions_test_zero_no_patch_before))

        # Project activations
        projected_val_patch = project_activations(autoencoder, val_activations_patch, device)
        projected_val_no_patch = project_activations(autoencoder, val_activations_no_patch, device)
        projected_two_test_patch = project_activations(autoencoder, test_two_patch, device)
        projected_two_test_no_patch = project_activations(autoencoder, test_two_no_patch, device)
        projected_zero_test_patch = project_activations(autoencoder, test_zero_patch, device)
        projected_zero_test_no_patch = project_activations(autoencoder, test_zero_no_patch, device)



        # Loop through percentages
        for percentage in range(0, 51):  # 1% to 15%
            print(f"Testing with {percentage}% muting...")

            # Calculate differences and load top neurons
            #abs_diff = np.abs(np.mean(projected_val_patch, axis=0) - np.mean(projected_val_no_patch, axis=0))
            #csv_path = save_all_neurons_to_csv(abs_diff, folder_name, filename=f"mnist_bg_val_neuron_differences_seed_{seed}.csv")
            #top_neurons = load_top_neurons_from_csv(folder_name, f"mnist_bg_val_neuron_differences_seed_{seed}.csv", percentage)


            # **Correlation-Based Neurons**
            correlation_csv_path = save_neurons_by_correlation(
                projected_val_patch, projected_val_no_patch, folder_name, filename=f"l1_neurons_by_correlation_seed_{seed}_25.csv"
            )
            top_neurons_corr = load_top_neurons_from_csv(folder_name, f"l1_neurons_by_correlation_seed_{seed}_25.csv", percentage)

            top_neurons = top_neurons_corr

            # Muting neurons
            projected_val_patch_muted = projected_val_patch.copy()
            projected_val_no_patch_muted = projected_val_no_patch.copy()
            projected_two_test_patch_muted = projected_two_test_patch.copy()
            projected_two_test_no_patch_muted = projected_two_test_no_patch.copy()
            projected_zero_test_patch_muted = projected_zero_test_patch.copy()
            projected_zero_test_no_patch_muted = projected_zero_test_no_patch.copy()

            projected_val_patch_muted[:, top_neurons] = 0
            projected_val_no_patch_muted[:, top_neurons] = 0
            projected_two_test_patch_muted[:, top_neurons] = 0
            projected_two_test_no_patch_muted[:, top_neurons] = 0
            projected_zero_test_patch_muted[:, top_neurons] = 0
            projected_zero_test_no_patch_muted[:, top_neurons] = 0

            # Decode and classify
            decoded_val_patch = autoencoder.decoder(torch.from_numpy(projected_val_patch_muted).to(device).float()).cpu().numpy()
            decoded_val_no_patch = autoencoder.decoder(torch.from_numpy(projected_val_no_patch_muted).to(device).float()).cpu().numpy()
            decoded_two_test_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_patch_muted).to(device).float()).cpu().numpy()
            decoded_two_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_no_patch_muted).to(device).float()).cpu().numpy()
            decoded_zero_test_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_patch_muted).to(device).float()).cpu().numpy()
            decoded_zero_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_no_patch_muted).to(device).float()).cpu().numpy()

            predictions_val_patch_after = classify_decoded_activations(model, decoded_val_patch)
            predictions_val_no_patch_after = classify_decoded_activations(model, decoded_val_no_patch)
            predictions_test_two_patch_after = classify_decoded_activations(model, decoded_two_test_patch)
            predictions_test_two_no_patch_after = classify_decoded_activations(model, decoded_two_test_no_patch)
            predictions_test_zero_patch_after = classify_decoded_activations(model, decoded_zero_test_patch)
            predictions_test_zero_no_patch_after = classify_decoded_activations(model, decoded_zero_test_no_patch)

            accuracy_val_patch_after = calculate_group_accuracy(predictions_val_patch_after, [0] * len(predictions_val_patch_after))
            accuracy_val_no_patch_after = calculate_group_accuracy(predictions_val_no_patch_after, [0] * len(predictions_val_no_patch_after))
            accuracy_test_two_patch_after = calculate_group_accuracy(predictions_test_two_patch_after, [1] * len(predictions_test_two_patch_after))
            accuracy_test_two_no_patch_after = calculate_group_accuracy(predictions_test_two_no_patch_after, [1] * len(predictions_test_two_no_patch_after))
            accuracy_test_zero_patch_after = calculate_group_accuracy(predictions_test_zero_patch_after, [0] * len(predictions_test_zero_patch_after))
            accuracy_test_zero_no_patch_after = calculate_group_accuracy(predictions_test_zero_no_patch_after, [0] * len(predictions_test_zero_no_patch_after))

            # Calculate worst and average group accuracies
            worst_acc_before = min(accuracy_test_two_patch_before, accuracy_test_two_no_patch_before)
            worst_acc_after = min(accuracy_test_two_patch_after, accuracy_test_two_no_patch_after)
            avg_acc_before = (accuracy_test_two_patch_before + accuracy_test_two_no_patch_before +
                              accuracy_test_zero_patch_before + accuracy_test_zero_no_patch_before) / 4
            avg_acc_after = (accuracy_test_two_patch_after + accuracy_test_two_no_patch_after +
                             accuracy_test_zero_patch_after + accuracy_test_zero_no_patch_after) / 4

            # Append results to DataFrame
            new_row = pd.DataFrame([{
                "Seed": seed,
                "Percentage": percentage,
                "Val_Patch_Before": accuracy_val_patch_before,
                "Val_NoPatch_Before": accuracy_val_no_patch_before,
                "Val_Patch_After": accuracy_val_patch_after,
                "Val_NoPatch_After": accuracy_val_no_patch_after,
                "Test_Two_Patch_Before": accuracy_test_two_patch_before,
                "Test_Two_Patch_After": accuracy_test_two_patch_after,
                "Test_Two_NoPatch_Before": accuracy_test_two_no_patch_before,
                "Test_Two_NoPatch_After": accuracy_test_two_no_patch_after,
                "Test_Zero_Patch_Before": accuracy_test_zero_patch_before,
                "Test_Zero_Patch_After": accuracy_test_zero_patch_after,
                "Test_Zero_NoPatch_Before": accuracy_test_zero_no_patch_before,
                "Test_Zero_NoPatch_After": accuracy_test_zero_no_patch_after,
                "Worst_Acc_Before": worst_acc_before,
                "Worst_Acc_After": worst_acc_after,
                "Avg_Acc_Before": avg_acc_before,
                "Avg_Acc_After": avg_acc_after
            }])

            # Save results to CSV
            results_df = pd.concat([results_df, new_row], ignore_index=True)
    results_csv_path = os.path.join(folder_name, "background_25.csv")
    results_df.to_csv(results_csv_path, index=False)
    print(f"All results saved to {results_csv_path}")

if __name__ == "__main__":
    main()

# %%
import torch
import os
from torch.utils.data import DataLoader
import torch.nn as nn
from datetime import datetime



# Function to load the trained model
def load_model(model_path, device):
    model = models.alexnet(pretrained=True)
    model.classifier[-1] = nn.Linear(4096, 2)
    model.load_state_dict(torch.load(model_path, map_location=device))
    params_to_update = model.parameters()
    model.to(device)
    model.eval()
    return model

# Function to test the model on a specific dataset
def test_model(model, dataloader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in dataloader:  # Ignore group_label
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total * 100
    return accuracy


# Define paths to the test datasets
test_two_bg_path = '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/test/class_2'
test_two_org_path = '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/test/class_2'
test_zero_bg_path = '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/background/test/class_0'
test_zero_org_path = '/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits/original/test/class_0'

# Create test datasets
dataset_test_two_bg = MnistDataset(path=test_two_bg_path, is_two=1)
dataset_test_two_org = MnistDataset(path=test_two_org_path, is_two=1)
dataset_test_zero_bg = MnistDataset(path=test_zero_bg_path, is_two=0)
dataset_test_zero_org = MnistDataset(path=test_zero_org_path, is_two=0)

# Create dataloaders for the test datasets
batch_size = 64
test_loader_two_bg = DataLoader(dataset_test_two_bg, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader_two_org = DataLoader(dataset_test_two_org, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader_zero_bg = DataLoader(dataset_test_zero_bg, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader_zero_org = DataLoader(dataset_test_zero_org, batch_size=batch_size, shuffle=False, num_workers=2)

# Set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load and test the model for each seed
seeds = [1, 11, 111]


for seed in seeds:
    model_path = f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnetmp_mnist_bg_seed_{seed}.pt"

    print(f"\nLoading model with seed {seed}")
    model = load_model(model_path, device)

    # Test on patches_left dataset
    accuracy_two_bg = test_model(model, test_loader_two_bg, device)
    print(f"Accuracy on colored background test dataset (class_2): {accuracy_two_bg:.2f}%")

    # Test on original dataset
    accuracy_two_org = test_model(model, test_loader_two_org, device)
    print(f"Accuracy on original background test dataset (class_2): {accuracy_two_org:.2f}%")

    accuracy_zero_org = test_model(model, test_loader_zero_org, device)
    print(f"Accuracy on original foreground test dataset (class_0): {accuracy_zero_org:.2f}%")
    accuracy_zero_bg = test_model(model, test_loader_zero_bg, device)
    print(f"Accuracy on colored foreground test dataset (class_0): {accuracy_zero_bg:.2f}%")

# %% [markdown]
# ## Archives

# %% [markdown]
# ####Archived SAE versions

# %%
'''
# Step 2: Define Sparse Autoencoder with KL-divergence
class SparseAutoencoder(nn.Module):
    def __init__(self, in_dims, h_dims, sparsity_lambda=1.5, sparsity_target=0.20, xavier_norm_init=True):
        super(SparseAutoencoder, self).__init__()
        self.in_dims = in_dims  # Input dimension (number of neurons in the input layer)
        self.h_dims = h_dims  # Hidden dimension (number of neurons in the hidden layer)
        self.sparsity_lambda = sparsity_lambda  # Weight for the sparsity penalty term
        self.sparsity_target = sparsity_target  # Target sparsity (desired average activation)

        # Encoder: Projects input to the hidden (sparse) space
        self.encoder = nn.Sequential(
            nn.Linear(self.in_dims, self.h_dims),
            nn.ReLU()
        )
        if xavier_norm_init:
            nn.init.xavier_uniform_(self.encoder[0].weight)  # Xavier initialization

        # Decoder: Reconstructs the input from the hidden (sparse) representation
        self.decoder = nn.Sequential(
            nn.Linear(self.h_dims, self.in_dims),
            nn.ReLU()
        )
        if xavier_norm_init:
            nn.init.xavier_uniform_(self.decoder[0].weight)

    # Forward pass through the encoder and decoder
    def forward(self, x):
        encoded = self.encoder(x)  # Pass input through encoder
        decoded = self.decoder(encoded)  # Pass encoded (sparse) representation through decoder
        return encoded, decoded

    # KL-divergence sparsity penalty calculation
    def sparsity_penalty(self, encoded):
        rho_hat = torch.mean(encoded, dim=0)  # Compute the average activation for each hidden neuron
        rho = torch.ones_like(rho_hat) * self.sparsity_target  # Target sparsity value
        epsilon = 1e-8  # Small value to avoid log(0)
        kl_divergence = F.kl_div((rho_hat + epsilon).log(), rho + epsilon, reduction='batchmean')  # KL-divergence
        return self.sparsity_lambda * kl_divergence  # Return the sparsity penalty, weighted by lambda

    # Loss function combining MSE (reconstruction error) and sparsity penalty
    def loss_function(self, decoded, original, encoded):
        mse_loss = F.mse_loss(decoded, original)  # Mean Squared Error for reconstruction
        sparsity_loss = self.sparsity_penalty(encoded)  # Sparsity penalty for hidden layer activations
        return mse_loss + sparsity_loss  # Total loss is MSE + sparsity penalty


# Early stopping mechanism to prevent overfitting
class EarlyStopping:
    def __init__(self, patience=30, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta  # Minimum change to qualify as an improvement
        self.best_loss = None  # Best validation loss observed so far
        self.counter = 0  # Counter to keep track of how many epochs since the last improvement

    # Check if training should be stopped based on validation loss
    def check(self, loss):
        if self.best_loss is None:
            self.best_loss = loss  # Set the initial best loss
            return False

        # If the loss has improved significantly
        if loss < self.best_loss - self.min_delta:
            self.best_loss = loss  # Update best loss
            self.counter = 0  # Reset counter
            return False
        else:
            self.counter += 1  # Increment counter if no improvement
            if self.counter >= self.patience:
                print("Early stopping triggered.")  # Stop training if patience is exceeded
                return True
        return False


# Training Function with Loss Tracking and Plotting
def train_autoencoder(autoencoder, train_data, val_data, num_epochs=500, batch_size=128, learning_rate=1e-5, validation_split=0.2, clip_gradients=True, max_grad_norm=0.5):
    #print(f"Training autoencoder with input dim {data.shape[1]} and encoding dim {autoencoder.h_dims}")

    # Split the data into training and validation sets
    #num_train = int((1 - validation_split) * len(data))  # Compute the number of training samples
    #train_data = data[:num_train]  # Training data
    #val_data = data[num_train:]  # Validation data

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    train_tensor = torch.from_numpy(train_data).float()
    val_tensor = torch.from_numpy(val_data).float()
    # Create PyTorch datasets and dataloaders for training and validation
    train_dataset = torch.utils.data.TensorDataset(torch.from_numpy(train_data).float())
    val_dataset = torch.utils.data.TensorDataset(torch.from_numpy(val_data).float())
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Adam optimizer with learning rate and weight decay for regularization
    optimizer = torch.optim.Adam(autoencoder.parameters(), lr=learning_rate, weight_decay=1e-2)

    # Initialize early stopping
    early_stopping = EarlyStopping(patience=30, min_delta=0.001)

    # Lists to store training and validation loss values
    train_losses = []
    val_losses = []

    # Start training loop
    autoencoder.train()  # Set the autoencoder in training mode
    for epoch in range(num_epochs):
        total_train_loss = 0  # Initialize training loss for the current epoch

        # Iterate over batches in the training set
        for x_batch, in train_loader:
            x_batch = x_batch.to(device)
            optimizer.zero_grad()  # Zero the gradients
            encoded, decoded = autoencoder(x_batch)  # Forward pass through autoencoder
            loss = autoencoder.loss_function(decoded, x_batch, encoded)  # Compute the loss
            loss.backward()  # Backpropagate the error

            # Apply gradient clipping if enabled
            if clip_gradients:
                torch.nn.utils.clip_grad_norm_(autoencoder.parameters(), max_grad_norm)

            optimizer.step()  # Update the weights using the optimizer
            total_train_loss += loss.item()  # Accumulate training loss for this batch

        # Validation step after each epoch
        total_val_loss = 0  # Initialize validation loss
        autoencoder.eval()  # Set the autoencoder in evaluation mode
        with torch.no_grad():  # No gradient calculation in validation mode
            for x_batch, in val_loader:
                x_batch = x_batch.to(device)
                encoded, decoded = autoencoder(x_batch)
                loss = autoencoder.loss_function(decoded, x_batch, encoded)
                total_val_loss += loss.item()

        # Compute the average training and validation loss for this epoch
        avg_train_loss = total_train_loss / len(train_loader)
        avg_val_loss = total_val_loss / len(val_loader)

        # Store the loss values for plotting later
        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # Print progress for the current epoch
        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {avg_train_loss}, Val Loss: {avg_val_loss}')

        # Check early stopping condition based on validation loss
        if early_stopping.check(avg_val_loss):
            break

    print("Autoencoder training completed")

    # Plot the training and validation loss over epochs
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
    plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss over Epochs')
    plt.legend()
    plt.grid(True)
    plt.show()

    return autoencoder
'''

# %%
'''
####THIS IS THE old v2  VERSION
# Define the directory to save autoencoders trained on normalized activations
save_sae_dir = '/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/mnist_bg'  # Directory to save the trained autoencoder
os.makedirs(save_sae_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Iterate through layers of interest
for layer in layers_of_interest:
    print(f'\nTraining autoencoders for layer {layer}')

    # Iterate through seeds (corresponding to models)
    for seed_idx, seed in enumerate([1, 11, 111], start=1):
        print(f"\nProcessing activations for layer {layer}, seed {seed} (Model {seed_idx})")

        # Get training activations for the current seed and layer
        train_activations_list = []
        print(f"\nTrain files associated with seed {seed}:")
        for subset in ['two_no_patch', 'zero_no_patch', 'zero_patch']:
            if subset in train_activations[layer]:
                subset_activations = train_activations[layer][subset][seed_idx - 1]  # Seed index starts from 1, Python lists are 0-based
                train_activations_list.append(subset_activations)
                print(f"  - Subset: {subset}, File: train_model{seed_idx}_{subset}.npy")
            else:
                print(f"Warning: No train activations found for subset {subset}, layer {layer}, seed {seed}.")

        if len(train_activations_list) == 0:
            print(f"No train activations found for layer {layer}, seed {seed}. Skipping...")
            continue

        # Combine train activations
        combined_train_activations = np.vstack(train_activations_list)
        print(f"Combined train activations shape for layer {layer}, seed {seed}: {combined_train_activations.shape}")

        # Get validation activations for the current seed and layer
        val_activations_list = []
        print(f"\nValidation files associated with seed {seed}:")
        for subset in ['two_no_patch', 'zero_no_patch', 'zero_patch']:
            if subset in val_activations[layer]:
                subset_activations = val_activations[layer][subset][seed_idx - 1]
                val_activations_list.append(subset_activations)
                print(f"  - Subset: {subset}, File: val_model{seed_idx}_{subset}.npy")
            else:
                print(f"Warning: No val activations found for subset {subset}, layer {layer}, seed {seed}.")

        if len(val_activations_list) == 0:
            print(f"No val activations found for layer {layer}, seed {seed}. Skipping...")
            continue

        # Combine val activations
        combined_val_activations = np.vstack(val_activations_list)
        print(f"Combined val activations shape for layer {layer}, seed {seed}: {combined_val_activations.shape}")

        # Set the random seed for reproducibility
        torch.manual_seed(seed)
        np.random.seed(seed)

        # Define encoding dimension
        encoding_dim = 16000

        # Train autoencoder on unnormalized activations
        autoencoder = SparseAutoencoder(combined_train_activations.shape[1], encoding_dim).to(device)
        print(f"Training autoencoder for layer {layer} (unnormalized, seed {seed})")
        autoencoder = train_autoencoder(autoencoder, combined_train_activations, combined_val_activations,
                                        num_epochs=500, learning_rate=1e-5)

        # Save the trained autoencoder
        save_path_unnormalized = os.path.join(
            save_sae_dir, f'bgy_autoencoder_layer_{layer}_seed_{seed}.pth'
        )
        torch.save(autoencoder.state_dict(), save_path_unnormalized)
        print(f"Saved unnormalized autoencoder at {save_path_unnormalized}")

        # Clear memory
        del autoencoder
        torch.cuda.empty_cache()
        gc.collect()

print("\nAll autoencoders trained and saved successfully.")
'''

# %%
'''
#### THIS IS AN OLD VERSION
# Define the directory to save autoencoders trained on normalized activations
save_sae_dir = '/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/mnist_bg'  # Directory to save the trained autoencoder
os.makedirs(save_sae_dir, exist_ok=True)

# Iterate through layers of interest
for layer in layers_of_interest:
    print(f'\nTraining autoencoders for layer {layer}')

    # Iterate through seeds (corresponding to models)
    for seed_idx, seed in enumerate([1, 11, 111], start=1):
        print(f"\nProcessing activations for layer {layer}, seed {seed} (Model {seed_idx})")

        # Get training activations for the current seed and layer
        train_activations_list = []
        print(f"\nTrain files associated with seed {seed}:")
        for subset in ['two_no_patch', 'zero_no_patch', 'zero_patch']:
            if subset in train_activations[layer]:
                subset_activations = train_activations[layer][subset][seed_idx - 1]  # Seed index starts from 1, Python lists are 0-based
                train_activations_list.append(subset_activations)
                print(f"  - Subset: {subset}, File: train_model{seed_idx}_{subset}.npy")
            else:
                print(f"Warning: No train activations found for subset {subset}, layer {layer}, seed {seed}.")

        if len(train_activations_list) == 0:
            print(f"No train activations found for layer {layer}, seed {seed}. Skipping...")
            continue

        # Combine train activations
        combined_train_activations = np.vstack(train_activations_list)
        print(f"Combined train activations shape for layer {layer}, seed {seed}: {combined_train_activations.shape}")

        # Get validation activations for the current seed and layer
        val_activations_list = []
        print(f"\nValidation files associated with seed {seed}:")
        for subset in ['two_no_patch', 'zero_no_patch', 'zero_patch']:
            if subset in val_activations[layer]:
                subset_activations = val_activations[layer][subset][seed_idx - 1]
                val_activations_list.append(subset_activations)
                print(f"  - Subset: {subset}, File: val_model{seed_idx}_{subset}.npy")
            else:
                print(f"Warning: No val activations found for subset {subset}, layer {layer}, seed {seed}.")

        if len(val_activations_list) == 0:
            print(f"No val activations found for layer {layer}, seed {seed}. Skipping...")
            continue

        # Combine val activations
        combined_val_activations = np.vstack(val_activations_list)
        print(f"Combined val activations shape for layer {layer}, seed {seed}: {combined_val_activations.shape}")

        # Set the random seed for reproducibility
        torch.manual_seed(seed)
        np.random.seed(seed)

        # Define encoding dimension
        encoding_dim = 8192

        # Train autoencoder on unnormalized activations
        autoencoder = SparseAutoencoder(combined_train_activations.shape[1], encoding_dim).to(device)
        print(f"Training autoencoder for layer {layer} (unnormalized, seed {seed})")
        autoencoder = train_autoencoder(autoencoder, combined_train_activations, combined_val_activations,
                                        num_epochs=500, learning_rate=1e-5)

        # Save the trained autoencoder
        save_path_unnormalized = os.path.join(
            save_sae_dir, f'bg_autoencoder_layer_{layer}_seed_{seed}_unnormalized.pth'
        )
        torch.save(autoencoder.state_dict(), save_path_unnormalized)
        print(f"Saved unnormalized autoencoder at {save_path_unnormalized}")

        # Clear memory
        del autoencoder
        torch.cuda.empty_cache()
        gc.collect()

print("\nAll autoencoders trained and saved successfully.")
'''

# %%
from sklearn.metrics import accuracy_score
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Function 12 to classify decoded activations
def classify_decoded_activations(model, decoded_activations):
    """Classify decoded activations using the softmax layer of the model."""
    predictions = []
    for activation in decoded_activations:
        # Convert numpy activation to a tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)

        # Pass through classifier[5] (ReLU)
        relu_output = model.classifier[5](activation_tensor)

        # Pass through classifier[6] (final linear layer)
        output = model.classifier[6](relu_output)

        # Apply softmax and get the predicted class
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)

    return predictions


# Project activations into sparse space
def project_activations(autoencoder, activations, device):
    print("Projecting Alexnet activations into SAE sparse space...")
    with torch.no_grad():
        projected = autoencoder.encoder(torch.from_numpy(activations).to(device).float())
    return projected.cpu().numpy()

# Save all neuron differences and indexes in descending order
def save_all_neurons_to_csv(abs_diff, folder_name, filename="bg_all_neuron_differences.csv"):
    """
    Save all neuron indexes sorted by their differences (descending order) to a CSV file.
    """
    print(f"Saving all neuron differences to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": np.arange(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

    return csv_path # return the csv_path



def save_top_neurons_to_csv(abs_diff, top_neurons, folder_name, filename="bg_top_neurons.csv"):
    """
    Save the top neurons with their difference values to a CSV file.
    """
    print(f"Saving top neurons to CSV file: {filename}")

    # Create a DataFrame with neuron indices and their absolute differences
    neuron_data = pd.DataFrame({
        "Neuron_Index": range(len(abs_diff)),
        "Activation_Difference": abs_diff
    })

    # Mark whether each neuron is in the top 10%
    neuron_data["Selected_for_Muting"] = neuron_data["Neuron_Index"].isin(top_neurons)

    # Sort by absolute difference in descending order
    neuron_data.sort_values(by="Activation_Difference", ascending=False, inplace=True)

    # Save the DataFrame to a CSV file
    csv_path = os.path.join(folder_name, filename)
    neuron_data.to_csv(csv_path, index=False)
    print(f"CSV saved at: {csv_path}")

# Function to load top neurons from CSV based on a percentage
def load_top_neurons_from_csv(folder_name, filename, percentage):
    """
    Load top neurons based on the specified percentage from the saved CSV file.
    """
    csv_path = os.path.join(folder_name, filename)
    neuron_data = pd.read_csv(csv_path)

    # Calculate the number of top neurons to select
    top_count = int(len(neuron_data) * (percentage / 100))

    # Select the top neurons based on their activation difference
    top_neurons = neuron_data.iloc[:top_count]["Neuron_Index"].values
    print(f"Loaded top {percentage}% neurons ({top_count} neurons) for muting.")
    return top_neurons


def classify_with_alexnet(model, activations):
    """
    Classify images using the original AlexNet classifier on the fc2 activations.
    """
    predictions = []
    for activation in activations:
        # Convert numpy activation to tensor
        activation_tensor = torch.from_numpy(activation).float().to(device)
        relu_output = model.classifier[5](activation_tensor)  # Apply ReLU
        output = model.classifier[6](relu_output)  # Apply fc3
        prediction = torch.argmax(torch.nn.functional.softmax(output, dim=0)).item()
        predictions.append(prediction)
    return predictions

# Function to calculate accuracy per group
def calculate_group_accuracy(predictions, true_labels):
    return accuracy_score(true_labels, predictions)



def main():

    seeds = [1, 11, 111]

    # Paths to models, activations, and autoencoders for each seed
    model_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/models/initial_classifier/alexnet_mnist_bg_seed_{seed}.pt"
        for seed in seeds
    ]
    autoencoder_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/Autoencoders/mnist_bg/l1_bg_autoencoder_layer_fc2_seed_{seed}.pth"
        for seed in seeds
    ]
    test_activation_two_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/alexnet_mnist_finetune_bg/fc2_activations_test_two_bg_alexnetmp_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_two_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/alexnet_mnist_finetune_bg/fc2_activations_test_two_org_alexnetmp_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/alexnet_mnist_finetune_bg/fc2_activations_test_zero_bg_alexnetmp_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    test_activation_zero_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/alexnet_mnist_finetune_bg/fc2_activations_test_zero_org_alexnetmp_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/alexnet_mnist_finetune_bg/fc2_activations_val_zero_bg_alexnetmp_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]
    val_activation_no_patch_paths = [
        f"/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/alexnet_mnist_finetune_bg/fc2_activations_val_zero_org_alexnetmp_mnist_bg_seed_{seed}.npy"
        for seed in seeds
    ]

    # Output folder for results
    folder_name = "/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/alexnet_mnist_finetune_bg"
    os.makedirs(folder_name, exist_ok=True)

    all_results = []

    # Loop through seeds/models/autoencoders
    for seed_idx, seed in enumerate(seeds):

        print(f"\nProcessing Seed {seed}")
        model_path = model_paths[seed_idx]
        sae_path = autoencoder_paths[seed_idx]
        val_patch_path = val_activation_patch_paths[seed_idx]
        val_no_patch_path = val_activation_no_patch_paths[seed_idx]
        test_two_patch_path = test_activation_two_patch_paths[seed_idx]
        test_two_no_patch_path = test_activation_two_no_patch_paths[seed_idx]
        test_zero_patch_path = test_activation_zero_patch_paths[seed_idx]
        test_zero_no_patch_path = test_activation_zero_no_patch_paths[seed_idx]

        print(f"Model Path: {model_path}")
        print(f"Autoencoder Path: {sae_path}")
        print(f"Validation Patch Path: {val_patch_path}")
        print(f"Validation No Patch Path: {val_no_patch_path}")
        print(f"Test Two Patch Path: {test_two_patch_path}")
        print(f"Test Two No Patch Path: {test_two_no_patch_path}")
        print(f"Test Zero Patch Path: {test_zero_patch_path}")
        print(f"Test Zero No Patch Path: {test_zero_no_patch_path}")

        # Load the model and autoencoder
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = load_model(model_path, device)
        autoencoder = load_autoencoder(device, sae_path)

        # Load pre-saved activations
        val_activations_patch = np.load(val_patch_path, allow_pickle=True)
        val_activations_no_patch = np.load(val_no_patch_path, allow_pickle=True)

        # Direct classification using AlexNet
        predictions_val_patch_alexnet = classify_with_alexnet(model, val_activations_patch)
        accuracy_val_patch_alexnet = accuracy_score([0] * len(predictions_val_patch_alexnet), predictions_val_patch_alexnet)

        predictions_val_no_patch_alexnet = classify_with_alexnet(model, val_activations_no_patch)
        accuracy_no_patch_alexnet = accuracy_score([0] * len(predictions_val_no_patch_alexnet), predictions_val_no_patch_alexnet)

        # Classification before muting
        predictions_val_patch_before = classify_with_alexnet(model, val_activations_patch)
        predictions_val_no_patch_before = classify_with_alexnet(model, val_activations_no_patch)

        # Calculate validation accuracies before muting
        accuracy_val_patch_before = calculate_group_accuracy(predictions_val_patch_before, [0] * len(predictions_val_patch_before))
        accuracy_val_no_patch_before = calculate_group_accuracy(predictions_val_no_patch_before, [0] * len(predictions_val_no_patch_before))



        # Project validation activations into sparse space
        projected_val_patch = project_activations(autoencoder, val_activations_patch, device)
        projected_val_no_patch = project_activations(autoencoder, val_activations_no_patch, device)

        # Calculate differences and save neuron indexes
        avg_val_patch = np.mean(projected_val_patch, axis=0)
        avg_val_no_patch = np.mean(projected_val_no_patch, axis=0)
        abs_diff = np.abs(avg_val_patch - avg_val_no_patch)
        csv_path = save_all_neurons_to_csv(abs_diff, folder_name, filename=f"val_neuron_differences_seed_{seed}.csv")

        csv_folder = "/content/drive/MyDrive/Masterthesis/Datasets/mnist/activations/difference_analysis/alexnet_mnist_finetune_bg"
        csv_filename = f"tmp_val_neuron_differences_seed_{seed}.csv"
        neurons_to_mute = load_top_neurons_from_csv(csv_folder, filename=f"val_neuron_differences_seed_{seed}.csv", percentage = 3)
        #neurons_to_mute = top_neurons[:int(len(top_neurons) * 0.1)]
        projected_val_patch[:, neurons_to_mute] = 0
        projected_val_no_patch[:, neurons_to_mute] = 0

        decoded_val_patch = autoencoder.decoder(torch.from_numpy(projected_val_patch).to(device).float()).cpu().numpy()
        decoded_val_no_patch = autoencoder.decoder(torch.from_numpy(projected_val_no_patch).to(device).float()).cpu().numpy()

        predictions_val_patch_after = classify_decoded_activations(model, decoded_val_patch)
        predictions_val_no_patch_after = classify_decoded_activations(model, decoded_val_no_patch)

        accuracy_val_patch_after = calculate_group_accuracy(predictions_val_patch_after, [0] * len(predictions_val_patch_after))
        accuracy_val_no_patch_after = calculate_group_accuracy(predictions_val_no_patch_after, [0] * len(predictions_val_no_patch_after))

        # Print Validation Results
        print(f"Validation Accuracy (Patch, Before Muting): {accuracy_val_patch_before:.4f}")
        print(f"Validation Accuracy (No Patch, Before Muting): {accuracy_val_no_patch_before:.4f}")
        print(f"Validation Accuracy (Patch, After Muting): {accuracy_val_patch_after:.4f}")
        print(f"Validation Accuracy (No Patch, After Muting): {accuracy_val_no_patch_after:.4f}")

############################################################################################################################################
        # Test Phase
        test_two_patch = np.load(test_activation_two_patch_paths[seed_idx], allow_pickle=True)
        test_two_no_patch = np.load(test_activation_two_no_patch_paths[seed_idx], allow_pickle=True)
        test_zero_patch = np.load(test_activation_zero_patch_paths[seed_idx], allow_pickle=True)
        test_zero_no_patch = np.load(test_activation_zero_no_patch_paths[seed_idx], allow_pickle=True)



        # Test classification before muting
        predictions_test_two_patch_before = classify_with_alexnet(model, test_two_patch)
        predictions_test_two_no_patch_before = classify_with_alexnet(model, test_two_no_patch)
        predictions_test_zero_patch_before = classify_with_alexnet(model, test_zero_patch)
        predictions_test_zero_no_patch_before = classify_with_alexnet(model, test_zero_no_patch)



        accuracy_test_two_patch_before = calculate_group_accuracy(predictions_test_two_patch_before, [1] * len(predictions_test_two_patch_before))
        accuracy_test_two_no_patch_before = calculate_group_accuracy(predictions_test_two_no_patch_before, [1] * len(predictions_test_two_no_patch_before))
        accuracy_test_zero_patch_before = calculate_group_accuracy(predictions_test_zero_patch_before, [0] * len(predictions_test_zero_patch_before))
        accuracy_test_zero_no_patch_before = calculate_group_accuracy(predictions_test_zero_no_patch_before, [0] * len(predictions_test_zero_no_patch_before))

        # Load top neurons from validation
        top_neurons = load_top_neurons_from_csv(csv_folder, filename=f"val_neuron_differences_seed_{seed}.csv", percentage=3)

        # Project test activations into sparse space
        projected_two_test_patch = project_activations(autoencoder, test_two_patch, device)
        projected_two_test_no_patch = project_activations(autoencoder, test_two_no_patch, device)
        projected_zero_test_patch = project_activations(autoencoder, test_zero_patch, device)
        projected_zero_test_no_patch = project_activations(autoencoder, test_zero_no_patch, device)

        #top_neuron_count = int(len(abs_diff) * 0.1)
        #top_neurons = np.argsort(abs_diff)[-top_neuron_count:]

        # Muting neurons in test data
        percentage = 10
        neurons_to_mute = load_top_neurons_from_csv(csv_folder, filename=f"val_neuron_differences_seed_{seed}.csv", percentage = 3)
        projected_two_test_patch[:, neurons_to_mute] = 0
        projected_two_test_no_patch[:, neurons_to_mute] = 0
        projected_zero_test_patch[:, neurons_to_mute] = 0
        projected_zero_test_no_patch[:, neurons_to_mute] = 0


        # Decode and classify test data
        decoded_two_test_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_patch).to(device).float()).cpu().detach().numpy()
        decoded_two_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_two_test_no_patch).to(device).float()).cpu().detach().numpy()
        decoded_zero_test_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_patch).to(device).float()).cpu().detach().numpy()
        decoded_zero_test_no_patch = autoencoder.decoder(torch.from_numpy(projected_zero_test_no_patch).to(device).float()).cpu().detach().numpy()

        # Classification
        predictions_test_two_patch_after = classify_decoded_activations(model, decoded_two_test_patch)
        predictions_test_two_no_patch_after = classify_decoded_activations(model, decoded_two_test_no_patch)
        predictions_test_zero_patch_after = classify_decoded_activations(model, decoded_zero_test_patch)
        predictions_test_zero_no_patch_after = classify_decoded_activations(model, decoded_zero_test_no_patch)

        accuracy_test_two_patch_after = calculate_group_accuracy(predictions_test_two_patch_after, [1] * len(predictions_test_two_patch_after))
        accuracy_test_two_no_patch_after = calculate_group_accuracy(predictions_test_two_no_patch_after, [1] * len(predictions_test_two_no_patch_after))
        accuracy_test_zero_patch_after = calculate_group_accuracy(predictions_test_zero_patch_after, [0]* len(predictions_test_zero_patch_after))
        accuracy_test_zero_no_patch_after = calculate_group_accuracy(predictions_test_zero_no_patch_after, [0] * len(predictions_test_zero_no_patch_after))

        # Calculate Worst and Average Group Accuracies
        worst_group_accuracy_before = min(accuracy_test_two_patch_before, accuracy_test_two_no_patch_before)
        worst_group_accuracy_after = min(accuracy_test_two_patch_after, accuracy_test_two_no_patch_after)

        # Calculate the average group accuracy correctly by dividing the sum of accuracies by 4
        avg_group_accuracy_before = (accuracy_test_two_patch_before + accuracy_test_two_no_patch_before + accuracy_test_zero_patch_before + accuracy_test_zero_no_patch_before) / 4
        avg_group_accuracy_after = (accuracy_test_two_patch_after + accuracy_test_two_no_patch_after + accuracy_test_zero_patch_after + accuracy_test_zero_no_patch_after) / 4
        # Print Test Results
        print(f"Test Accuracy (Patch, Before Muting): {accuracy_test_two_patch_before:.4f}")
        print(f"Test Accuracy (No Patch, Before Muting): {accuracy_test_two_no_patch_before:.4f}")
        print(f"Test Accuracy (Patch, After Muting): {accuracy_test_zero_patch_after:.4f}")
        print(f"Test Accuracy (No Patch, After Muting): {accuracy_test_zero_no_patch_after:.4f}")
        print(f"Worst Group Accuracy (Before Muting): {worst_group_accuracy_before:.4f}")
        print(f"Worst Group Accuracy (After Muting): {worst_group_accuracy_after:.4f}")
        print(f"Average Group Accuracy (Before Muting): {avg_group_accuracy_before:.4f}")
        print(f"Average Group Accuracy (After Muting): {avg_group_accuracy_after:.4f}")


if __name__ == "__main__":
    main()

# %%
base_dir = "/content/drive/MyDrive/Masterthesis/Datasets/mnist/dataset_splits"

# Function to count images in each folder and subfolder
def count_images_in_directory(directory):
    image_count = {}
    for root, _, files in os.walk(directory):
        image_files = [file for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg'))]
        image_count[root] = len(image_files)
    return image_count

image_counts = count_images_in_directory(base_dir)

for folder, count in image_counts.items():
    print(f"Folder: {folder}, Image Count: {count}")
